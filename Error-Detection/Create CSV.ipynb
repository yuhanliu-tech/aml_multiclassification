# %% [markdown]
# option 1: convert to csv file- https://pub.towardsai.net/how-to-create-a-new-custom-dataset-from-images-9b95977964ab

# %% [markdown]
# LABELS
#
# **** 5 buckets:
#
# C: Close (0)
#
# F: Far (1)
#
# H: HighP (2)
#
# L: LowP (3)
#
# G: Good (4)
#
# ***** 3 buckets
#
# O: Overextruded (0)
# G: Good (1)
# U: Underextruded (2)

# %%
# Convert the images into a CSV
# Run the following code to convert all the images into a CSV and label them accordingly.

from PIL import Image
import numpy as np
import sys
import os
import csv

# %%
# default format can be changed as needed
def createFileList(myDir, format='.png'):
    fileList = []
    print(myDir)
    labels = []
    names = []
    keywords = {"O" : "0","G": "1", "U" : "2"} # keys and values updated to test data
    for root, dirs, files in os.walk(myDir, topdown=True):
        for name in files:
            if name.endswith(format):
                fullName = os.path.join(root, name)
                fileList.append(fullName)
            for keyword in keywords:
                if keyword in name:
                    labels.append(keywords[keyword])
            names.append(name)
    return fileList, labels, names

def createCSV(test_or_train):
    
    # load the original image
    myFileList, labels, names  = createFileList('Processed Data (3 buckets)/Training/')
    csv_name = "training_3buckets.csv"
    
    if (test_or_train == "test"):
        # load the original image
        myFileList, labels, names  = createFileList('Processed Data (3 buckets)/Test/')
        csv_name = "test_3buckets.csv"
        
    i = 0
    for file in myFileList:
        print(file)
        img_file = Image.open(file)
        # img_file.show()
    # get original image parameters...
        width, height = img_file.size
        format = img_file.format
        mode = img_file.mode
    # Make image Greyscale
        img_grey = img_file.convert('RGB') # L for greyscale, RGB for colored - can probably just use greyscale later? 
        #img_grey.save('result.png')
        #img_grey.show()
    # Save Greyscale values
        value = np.asarray(img_grey.getdata(), dtype=np.int).reshape((width, height, 3)) # must add third parameter 3 for RGB
        value = value.flatten()

        value = np.append(value,labels[i])
        i +=1

        print(value)
        with open(csv_name, 'a') as f: # save file as test_data.csv
            writer = csv.writer(f)
            writer.writerow(value)

# %%
createCSV("test")
createCSV("train")
# Out:
# Processed Data (3 buckets)/Training/
# Processed Data (3 buckets)/Test/
# Processed Data (3 buckets)/Test/Good (100).png
# ['146' '104' '121' ... '68' '127' '1']
# Processed Data (3 buckets)/Test/Good (101).png
# ['132' '97' '121' ... '67' '128' '1']
# Processed Data (3 buckets)/Test/Good (11).png
# ['127' '103' '119' ... '96' '124' '1']
# Processed Data (3 buckets)/Test/Good (118).png
# ['198' '156' '150' ... '80' '130' '1']
# Processed Data (3 buckets)/Test/Good (119).png
# ['150' '106' '123' ... '69' '128' '1']
# Processed Data (3 buckets)/Test/Good (127).png
# ['119' '77' '101' ... '62' '111' '1']
# Processed Data (3 buckets)/Test/Good (129).png
# ['115' '81' '113' ... '61' '120' '1']
# Processed Data (3 buckets)/Test/Good (132).png
# ['123' '85' '113' ... '62' '121' '1']
# Processed Data (3 buckets)/Test/Good (141).png
# ['215' '164' '144' ... '68' '125' '1']
# Processed Data (3 buckets)/Test/Good (16).png
# ['155' '116' '119' ... '59' '111' '1']
# Processed Data (3 buckets)/Test/Good (175).png
# ['127' '116' '112' ... '98' '92' '1']
# Processed Data (3 buckets)/Test/Good (179).png
# ['132' '120' '117' ... '98' '98' '1']
# Processed Data (3 buckets)/Test/Good (180).png
# ['124' '114' '110' ... '93' '94' '1']
# Processed Data (3 buckets)/Test/Good (185).png
# ['125' '113' '103' ... '95' '89' '1']
# Processed Data (3 buckets)/Test/Good (192).png
# ['125' '96' '118' ... '89' '123' '1']
# Processed Data (3 buckets)/Test/Good (194).png
# ['124' '94' '118' ... '91' '122' '1']
# Processed Data (3 buckets)/Test/Good (196).png
# ['121' '93' '119' ... '96' '125' '1']
# Processed Data (3 buckets)/Test/Good (198).png
# ['124' '94' '121' ... '98' '126' '1']
# Processed Data (3 buckets)/Test/Good (2).png
# ['170' '134' '128' ... '64' '109' '1']
# Processed Data (3 buckets)/Test/Good (201).png
# ['121' '93' '118' ... '100' '127' '1']
# Processed Data (3 buckets)/Test/Good (202).png
# ['120' '92' '118' ... '99' '127' '1']
# Processed Data (3 buckets)/Test/Good (205).png
# ['118' '90' '118' ... '99' '128' '1']
# Processed Data (3 buckets)/Test/Good (207).png
# ['117' '90' '118' ... '98' '127' '1']
# Processed Data (3 buckets)/Test/Good (208).png
# ['117' '90' '112' ... '95' '121' '1']
# Processed Data (3 buckets)/Test/Good (211).png
# ['120' '91' '115' ... '101' '125' '1']
# Processed Data (3 buckets)/Test/Good (213).png
# ['121' '92' '117' ... '103' '130' '1']
# Processed Data (3 buckets)/Test/Good (224).png
# ['122' '93' '117' ... '90' '123' '1']
# Processed Data (3 buckets)/Test/Good (228).png
# ['127' '103' '123' ... '97' '128' '1']
# Processed Data (3 buckets)/Test/Good (231).png
# ['129' '105' '126' ... '97' '128' '1']
# Processed Data (3 buckets)/Test/Good (236).png
# ['99' '73' '116' ... '81' '130' '1']
# Processed Data (3 buckets)/Test/Good (238).png
# ['112' '83' '123' ... '81' '130' '1']
# Processed Data (3 buckets)/Test/Good (239).png
# ['143' '83' '72' ... '74' '79' '1']
# Processed Data (3 buckets)/Test/Good (24).png
# ['158' '126' '130' ... '74' '116' '1']
# Processed Data (3 buckets)/Test/Good (240).png
# ['151' '87' '73' ... '74' '78' '1']
# Processed Data (3 buckets)/Test/Good (241).png
# ['152' '89' '71' ... '72' '78' '1']
# Processed Data (3 buckets)/Test/Good (257).png
# ['143' '105' '122' ... '88' '125' '1']
# Processed Data (3 buckets)/Test/Good (258).png
# ['146' '106' '125' ... '89' '129' '1']
# Processed Data (3 buckets)/Test/Good (260).png
# ['140' '105' '128' ... '90' '131' '1']
# Processed Data (3 buckets)/Test/Good (263).png
# ['141' '107' '130' ... '90' '132' '1']
# Processed Data (3 buckets)/Test/Good (264).png
# ['144' '107' '136' ... '90' '138' '1']
# Processed Data (3 buckets)/Test/Good (277).png
# ['139' '105' '135' ... '91' '140' '1']
# Processed Data (3 buckets)/Test/Good (28).png
# ['141' '103' '125' ... '73' '129' '1']
# Processed Data (3 buckets)/Test/Good (280).png
# ['136' '102' '128' ... '94' '132' '1']
# Processed Data (3 buckets)/Test/Good (289).png
# ['125' '94' '130' ... '100' '140' '1']
# Processed Data (3 buckets)/Test/Good (290).png
# ['124' '92' '130' ... '100' '139' '1']
# <ipython-input-8-0c2e1e454b74>:44: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   value = np.asarray(img_grey.getdata(), dtype=np.int).reshape((width, height, 3)) # must add third parameter 3 for RGB
# Processed Data (3 buckets)/Test/Good (295).png
# ['123' '91' '122' ... '92' '131' '1']
# Processed Data (3 buckets)/Test/Good (30).png
# ['119' '101' '95' ... '93' '99' '1']
# Processed Data (3 buckets)/Test/Good (303).png
# ['127' '95' '129' ... '106' '140' '1']
# Processed Data (3 buckets)/Test/Good (305).png
# ['117' '92' '125' ... '105' '136' '1']
# Processed Data (3 buckets)/Test/Good (310).png
# ['116' '90' '125' ... '106' '136' '1']
# Processed Data (3 buckets)/Test/Good (311).png
# ['115' '89' '123' ... '106' '138' '1']
# Processed Data (3 buckets)/Test/Good (312).png
# ['113' '88' '122' ... '105' '134' '1']
# Processed Data (3 buckets)/Test/Good (317).png
# ['116' '90' '130' ... '107' '143' '1']
# Processed Data (3 buckets)/Test/Good (340).png
# ['120' '105' '95' ... '138' '115' '1']
# Processed Data (3 buckets)/Test/Good (343).png
# ['119' '105' '97' ... '140' '122' '1']
# Processed Data (3 buckets)/Test/Good (345).png
# ['123' '107' '99' ... '143' '124' '1']
# Processed Data (3 buckets)/Test/Good (346).png
# ['124' '107' '100' ... '142' '124' '1']
# Processed Data (3 buckets)/Test/Good (35).png
# ['180' '150' '120' ... '74' '87' '1']
# Processed Data (3 buckets)/Test/Good (356).png
# ['77' '62' '106' ... '161' '166' '1']
# Processed Data (3 buckets)/Test/Good (36).png
# ['141' '118' '102' ... '69' '84' '1']
# Processed Data (3 buckets)/Test/Good (37).png
# ['103' '87' '85' ... '52' '78' '1']
# Processed Data (3 buckets)/Test/Good (371).png
# ['132' '117' '105' ... '111' '106' '1']
# Processed Data (3 buckets)/Test/Good (374).png
# ['134' '119' '108' ... '109' '105' '1']
# Processed Data (3 buckets)/Test/Good (392).png
# ['133' '115' '104' ... '104' '102' '1']
# Processed Data (3 buckets)/Test/Good (398).png
# ['136' '115' '101' ... '117' '105' '1']
# Processed Data (3 buckets)/Test/Good (402).png
# ['128' '112' '102' ... '122' '113' '1']
# Processed Data (3 buckets)/Test/Good (405).png
# ['128' '113' '104' ... '120' '110' '1']
# Processed Data (3 buckets)/Test/Good (408).png
# ['121' '107' '99' ... '117' '107' '1']
# Processed Data (3 buckets)/Test/Good (41).png
# ['233' '196' '168' ... '97' '129' '1']
# Processed Data (3 buckets)/Test/Good (417).png
# ['122' '106' '97' ... '123' '109' '1']
# Processed Data (3 buckets)/Test/Good (418).png
# ['122' '106' '98' ... '124' '111' '1']
# Processed Data (3 buckets)/Test/Good (427).png
# ['111' '96' '91' ... '123' '111' '1']
# Processed Data (3 buckets)/Test/Good (428).png
# ['111' '97' '91' ... '125' '112' '1']
# Processed Data (3 buckets)/Test/Good (43).png
# ['128' '106' '101' ... '78' '98' '1']
# Processed Data (3 buckets)/Test/Good (436).png
# ['102' '92' '90' ... '131' '120' '1']
# Processed Data (3 buckets)/Test/Good (437).png
# ['106' '96' '93' ... '127' '116' '1']
# Processed Data (3 buckets)/Test/Good (440).png
# ['114' '101' '93' ... '103' '98' '1']
# Processed Data (3 buckets)/Test/Good (452).png
# ['147' '133' '128' ... '161' '147' '1']
# Processed Data (3 buckets)/Test/Good (46).png
# ['158' '121' '124' ... '60' '117' '1']
# Processed Data (3 buckets)/Test/Good (471).png
# ['135' '118' '109' ... '110' '104' '1']
# Processed Data (3 buckets)/Test/Good (476).png
# ['138' '120' '109' ... '111' '102' '1']
# Processed Data (3 buckets)/Test/Good (478).png
# ['138' '121' '110' ... '109' '103' '1']
# Processed Data (3 buckets)/Test/Good (486).png
# ['122' '107' '99' ... '103' '94' '1']
# Processed Data (3 buckets)/Test/Good (488).png
# ['121' '105' '99' ... '104' '97' '1']
# Processed Data (3 buckets)/Test/Good (512).png
# ['115' '101' '94' ... '113' '103' '1']
# Processed Data (3 buckets)/Test/Good (517).png
# ['115' '101' '97' ... '128' '115' '1']
# Processed Data (3 buckets)/Test/Good (519).png
# ['123' '108' '100' ... '147' '125' '1']
# Processed Data (3 buckets)/Test/Good (52).png
# ['163' '131' '127' ... '66' '109' '1']
# Processed Data (3 buckets)/Test/Good (531).png
# ['134' '123' '113' ... '146' '129' '1']
# Processed Data (3 buckets)/Test/Good (534).png
# ['119' '108' '104' ... '136' '124' '1']
# Processed Data (3 buckets)/Test/Good (535).png
# ['121' '111' '104' ... '139' '125' '1']
# Processed Data (3 buckets)/Test/Good (546).png
# ['130' '115' '112' ... '122' '120' '1']
# Processed Data (3 buckets)/Test/Good (547).png
# ['134' '117' '112' ... '125' '118' '1']
# Processed Data (3 buckets)/Test/Good (550).png
# ['125' '109' '101' ... '114' '107' '1']
# Processed Data (3 buckets)/Test/Good (570).png
# ['126' '110' '104' ... '127' '115' '1']
# Processed Data (3 buckets)/Test/Good (571).png
# ['126' '110' '105' ... '126' '113' '1']
# Processed Data (3 buckets)/Test/Good (573).png
# ['126' '110' '103' ... '130' '113' '1']
# Processed Data (3 buckets)/Test/Good (577).png
# ['112' '98' '95' ... '124' '109' '1']
# Processed Data (3 buckets)/Test/Good (58).png
# ['140' '95' '111' ... '72' '121' '1']
# Processed Data (3 buckets)/Test/Good (580).png
# ['109' '95' '92' ... '124' '109' '1']
# Processed Data (3 buckets)/Test/Good (582).png
# ['108' '95' '90' ... '128' '111' '1']
# Processed Data (3 buckets)/Test/Good (583).png
# ['110' '97' '92' ... '130' '112' '1']
# Processed Data (3 buckets)/Test/Good (585).png
# ['114' '100' '95' ... '132' '114' '1']
# Processed Data (3 buckets)/Test/Good (588).png
# ['111' '98' '93' ... '126' '107' '1']
# Processed Data (3 buckets)/Test/Good (592).png
# ['118' '104' '97' ... '135' '114' '1']
# Processed Data (3 buckets)/Test/Good (594).png
# ['132' '118' '105' ... '142' '119' '1']
# Processed Data (3 buckets)/Test/Good (595).png
# ['134' '120' '108' ... '144' '120' '1']
# Processed Data (3 buckets)/Test/Good (60).png
# ['149' '110' '124' ... '76' '133' '1']
# Processed Data (3 buckets)/Test/Good (601).png
# ['115' '113' '75' ... '129' '85' '1']
# Processed Data (3 buckets)/Test/Good (602).png
# ['118' '108' '117' ... '157' '148' '1']
# Processed Data (3 buckets)/Test/Good (603).png
# ['123' '113' '121' ... '156' '142' '1']
# Processed Data (3 buckets)/Test/Good (605).png
# ['129' '118' '125' ... '152' '138' '1']
# Processed Data (3 buckets)/Test/Good (613).png
# ['142' '129' '127' ... '117' '109' '1']
# Processed Data (3 buckets)/Test/Good (614).png
# ['141' '128' '125' ... '115' '109' '1']
# Processed Data (3 buckets)/Test/Good (632).png
# ['136' '121' '116' ... '101' '98' '1']
# Processed Data (3 buckets)/Test/Good (635).png
# ['135' '120' '114' ... '102' '100' '1']
# Processed Data (3 buckets)/Test/Good (642).png
# ['135' '121' '115' ... '107' '101' '1']
# Processed Data (3 buckets)/Test/Good (647).png
# ['139' '125' '118' ... '119' '109' '1']
# Processed Data (3 buckets)/Test/Good (648).png
# ['139' '125' '119' ... '119' '110' '1']
# Processed Data (3 buckets)/Test/Good (649).png
# ['142' '126' '120' ... '122' '113' '1']
# Processed Data (3 buckets)/Test/Good (651).png
# ['128' '115' '109' ... '117' '105' '1']
# Processed Data (3 buckets)/Test/Good (667).png
# ['117' '105' '99' ... '137' '112' '1']
# Processed Data (3 buckets)/Test/Good (8).png
# ['119' '94' '111' ... '66' '113' '1']
# Processed Data (3 buckets)/Test/Good (81).png
# ['181' '145' '139' ... '74' '122' '1']
# Processed Data (3 buckets)/Test/Good (85).png
# ['125' '94' '118' ... '82' '125' '1']
# Processed Data (3 buckets)/Test/Good (96).png
# ['135' '97' '127' ... '69' '133' '1']
# Processed Data (3 buckets)/Test/Good (98).png
# ['141' '103' '128' ... '70' '133' '1']
# Processed Data (3 buckets)/Test/Over_Far (100).png
# ['140' '124' '114' ... '136' '122' '0']
# Processed Data (3 buckets)/Test/Over_Far (101).png
# ['138' '123' '115' ... '141' '127' '0']
# Processed Data (3 buckets)/Test/Over_Far (109).png
# ['121' '111' '109' ... '117' '110' '0']
# Processed Data (3 buckets)/Test/Over_Far (117).png
# ['114' '94' '117' ... '161' '148' '0']
# Processed Data (3 buckets)/Test/Over_Far (118).png
# ['116' '96' '117' ... '160' '145' '0']
# Processed Data (3 buckets)/Test/Over_Far (125).png
# ['185' '128' '66' ... '117' '55' '0']
# Processed Data (3 buckets)/Test/Over_Far (127).png
# ['194' '132' '68' ... '119' '57' '0']
# Processed Data (3 buckets)/Test/Over_Far (130).png
# ['176' '130' '79' ... '109' '65' '0']
# Processed Data (3 buckets)/Test/Over_Far (14).png
# ['118' '116' '74' ... '148' '95' '0']
# Processed Data (3 buckets)/Test/Over_Far (158).png
# ['110' '93' '129' ... '154' '164' '0']
# Processed Data (3 buckets)/Test/Over_Far (172).png
# ['122' '110' '114' ... '132' '126' '0']
# Processed Data (3 buckets)/Test/Over_Far (176).png
# ['118' '106' '111' ... '137' '125' '0']
# Processed Data (3 buckets)/Test/Over_Far (178).png
# ['109' '103' '108' ... '133' '121' '0']
# Processed Data (3 buckets)/Test/Over_Far (182).png
# ['108' '101' '102' ... '128' '117' '0']
# Processed Data (3 buckets)/Test/Over_Far (19).png
# ['194' '125' '61' ... '139' '57' '0']
# Processed Data (3 buckets)/Test/Over_Far (191).png
# ['134' '116' '147' ... '135' '153' '0']
# Processed Data (3 buckets)/Test/Over_Far (193).png
# ['128' '118' '132' ... '113' '122' '0']
# Processed Data (3 buckets)/Test/Over_Far (195).png
# ['144' '132' '140' ... '115' '121' '0']
# Processed Data (3 buckets)/Test/Over_Far (197).png
# ['138' '127' '135' ... '110' '113' '0']
# Processed Data (3 buckets)/Test/Over_Far (2).png
# ['137' '112' '132' ... '93' '126' '0']
# Processed Data (3 buckets)/Test/Over_Far (20).png
# ['191' '131' '65' ... '117' '56' '0']
# Processed Data (3 buckets)/Test/Over_Far (202).png
# ['131' '119' '122' ... '121' '119' '0']
# Processed Data (3 buckets)/Test/Over_Far (204).png
# ['124' '112' '122' ... '119' '122' '0']
# Processed Data (3 buckets)/Test/Over_Far (205).png
# ['124' '112' '123' ... '121' '124' '0']
# Processed Data (3 buckets)/Test/Over_Far (209).png
# ['123' '112' '120' ... '126' '125' '0']
# Processed Data (3 buckets)/Test/Over_Far (210).png
# ['124' '112' '121' ... '128' '128' '0']
# Processed Data (3 buckets)/Test/Over_Far (221).png
# ['109' '99' '103' ... '128' '120' '0']
# Processed Data (3 buckets)/Test/Over_Far (224).png
# ['105' '98' '105' ... '124' '121' '0']
# Processed Data (3 buckets)/Test/Over_Far (228).png
# ['122' '102' '104' ... '77' '101' '0']
# Processed Data (3 buckets)/Test/Over_Far (232).png
# ['142' '119' '110' ... '73' '94' '0']
# Processed Data (3 buckets)/Test/Over_Far (234).png
# ['157' '131' '116' ... '71' '92' '0']
# Processed Data (3 buckets)/Test/Over_Far (235).png
# ['161' '136' '119' ... '71' '92' '0']
# Processed Data (3 buckets)/Test/Over_Far (236).png
# ['152' '128' '113' ... '70' '90' '0']
# Processed Data (3 buckets)/Test/Over_Far (237).png
# ['151' '126' '112' ... '68' '89' '0']
# Processed Data (3 buckets)/Test/Over_Far (238).png
# ['157' '132' '114' ... '68' '88' '0']
# Processed Data (3 buckets)/Test/Over_Far (252).png
# ['137' '115' '109' ... '79' '96' '0']
# Processed Data (3 buckets)/Test/Over_Far (253).png
# ['156' '131' '116' ... '82' '97' '0']
# Processed Data (3 buckets)/Test/Over_Far (255).png
# ['158' '138' '125' ... '79' '98' '0']
# Processed Data (3 buckets)/Test/Over_Far (258).png
# ['169' '141' '120' ... '72' '90' '0']
# Processed Data (3 buckets)/Test/Over_Far (259).png
# ['161' '142' '123' ... '68' '88' '0']
# Processed Data (3 buckets)/Test/Over_Far (271).png
# ['172' '144' '122' ... '67' '88' '0']
# Processed Data (3 buckets)/Test/Over_Far (274).png
# ['137' '115' '105' ... '66' '88' '0']
# Processed Data (3 buckets)/Test/Over_Far (275).png
# ['131' '110' '105' ... '69' '90' '0']
# Processed Data (3 buckets)/Test/Over_Far (283).png
# ['172' '144' '123' ... '68' '90' '0']
# Processed Data (3 buckets)/Test/Over_Far (285).png
# ['171' '144' '122' ... '68' '89' '0']
# Processed Data (3 buckets)/Test/Over_Far (289).png
# ['162' '141' '128' ... '67' '93' '0']
# Processed Data (3 buckets)/Test/Over_Far (294).png
# ['127' '102' '125' ... '87' '128' '0']
# Processed Data (3 buckets)/Test/Over_Far (298).png
# ['153' '130' '117' ... '85' '102' '0']
# Processed Data (3 buckets)/Test/Over_Far (3).png
# ['148' '116' '129' ... '90' '123' '0']
# Processed Data (3 buckets)/Test/Over_Far (304).png
# ['143' '125' '117' ... '70' '96' '0']
# Processed Data (3 buckets)/Test/Over_Far (305).png
# ['158' '138' '122' ... '71' '94' '0']
# Processed Data (3 buckets)/Test/Over_Far (306).png
# ['168' '147' '128' ... '70' '94' '0']
# Processed Data (3 buckets)/Test/Over_Far (310).png
# ['98' '74' '128' ... '101' '144' '0']
# Processed Data (3 buckets)/Test/Over_Far (35).png
# ['127' '116' '119' ... '98' '101' '0']
# Processed Data (3 buckets)/Test/Over_Far (38).png
# ['119' '108' '115' ... '133' '127' '0']
# Processed Data (3 buckets)/Test/Over_Far (4).png
# ['88' '65' '117' ... '97' '133' '0']
# Processed Data (3 buckets)/Test/Over_Far (40).png
# ['130' '90' '118' ... '63' '125' '0']
# Processed Data (3 buckets)/Test/Over_Far (44).png
# ['173' '146' '120' ... '57' '80' '0']
# Processed Data (3 buckets)/Test/Over_Far (50).png
# ['164' '144' '126' ... '76' '97' '0']
# Processed Data (3 buckets)/Test/Over_Far (54).png
# ['139' '114' '137' ... '98' '132' '0']
# Processed Data (3 buckets)/Test/Over_Far (64).png
# ['141' '129' '121' ... '157' '137' '0']
# Processed Data (3 buckets)/Test/Over_Far (66).png
# ['139' '126' '123' ... '135' '125' '0']
# Processed Data (3 buckets)/Test/Over_Far (69).png
# ['145' '136' '129' ... '120' '114' '0']
# Processed Data (3 buckets)/Test/Over_Far (87).png
# ['142' '132' '124' ... '119' '115' '0']
# Processed Data (3 buckets)/Test/Over_Far (92).png
# ['139' '130' '123' ... '132' '123' '0']
# Processed Data (3 buckets)/Test/Over_Far (98).png
# ['134' '125' '121' ... '137' '130' '0']
# Processed Data (3 buckets)/Test/Over_High (10).png
# ['138' '110' '124' ... '81' '124' '0']
# Processed Data (3 buckets)/Test/Over_High (102).png
# ['110' '96' '88' ... '124' '103' '0']
# Processed Data (3 buckets)/Test/Over_High (104).png
# ['110' '96' '92' ... '123' '108' '0']
# Processed Data (3 buckets)/Test/Over_High (111).png
# ['95' '89' '54' ... '107' '65' '0']
# Processed Data (3 buckets)/Test/Over_High (112).png
# ['96' '90' '56' ... '111' '69' '0']
# Processed Data (3 buckets)/Test/Over_High (121).png
# ['106' '105' '77' ... '96' '64' '0']
# Processed Data (3 buckets)/Test/Over_High (122).png
# ['110' '109' '78' ... '95' '63' '0']
# Processed Data (3 buckets)/Test/Over_High (124).png
# ['116' '113' '81' ... '94' '61' '0']
# Processed Data (3 buckets)/Test/Over_High (130).png
# ['150' '139' '130' ... '111' '106' '0']
# Processed Data (3 buckets)/Test/Over_High (131).png
# ['148' '138' '129' ... '110' '104' '0']
# Processed Data (3 buckets)/Test/Over_High (135).png
# ['135' '124' '82' ... '95' '60' '0']
# Processed Data (3 buckets)/Test/Over_High (147).png
# ['113' '109' '75' ... '134' '87' '0']
# Processed Data (3 buckets)/Test/Over_High (154).png
# ['121' '120' '86' ... '135' '92' '0']
# Processed Data (3 buckets)/Test/Over_High (166).png
# ['143' '129' '123' ... '124' '113' '0']
# Processed Data (3 buckets)/Test/Over_High (170).png
# ['114' '112' '82' ... '94' '65' '0']
# Processed Data (3 buckets)/Test/Over_High (172).png
# ['119' '117' '85' ... '96' '66' '0']
# Processed Data (3 buckets)/Test/Over_High (180).png
# ['120' '116' '83' ... '93' '63' '0']
# Processed Data (3 buckets)/Test/Over_High (182).png
# ['147' '137' '126' ... '108' '104' '0']
# Processed Data (3 buckets)/Test/Over_High (206).png
# ['109' '99' '102' ... '109' '103' '0']
# Processed Data (3 buckets)/Test/Over_High (210).png
# ['100' '98' '67' ... '108' '68' '0']
# Processed Data (3 buckets)/Test/Over_High (212).png
# ['114' '97' '119' ... '187' '170' '0']
# Processed Data (3 buckets)/Test/Over_High (213).png
# ['132' '114' '132' ... '190' '172' '0']
# Processed Data (3 buckets)/Test/Over_High (225).png
# ['138' '128' '119' ... '108' '100' '0']
# Processed Data (3 buckets)/Test/Over_High (228).png
# ['147' '130' '121' ... '110' '106' '0']
# Processed Data (3 buckets)/Test/Over_High (229).png
# ['143' '128' '119' ... '110' '103' '0']
# Processed Data (3 buckets)/Test/Over_High (24).png
# ['113' '110' '79' ... '93' '61' '0']
# Processed Data (3 buckets)/Test/Over_High (240).png
# ['66' '57' '85' ... '105' '120' '0']
# Processed Data (3 buckets)/Test/Over_High (244).png
# ['121' '113' '118' ... '110' '108' '0']
# Processed Data (3 buckets)/Test/Over_High (264).png
# ['129' '119' '111' ... '131' '113' '0']
# Processed Data (3 buckets)/Test/Over_High (265).png
# ['130' '119' '111' ... '135' '115' '0']
# Processed Data (3 buckets)/Test/Over_High (267).png
# ['100' '97' '63' ... '117' '71' '0']
# Processed Data (3 buckets)/Test/Over_High (270).png
# ['148' '115' '128' ... '73' '124' '0']
# Processed Data (3 buckets)/Test/Over_High (273).png
# ['157' '124' '130' ... '70' '123' '0']
# Processed Data (3 buckets)/Test/Over_High (274).png
# ['160' '126' '130' ... '71' '122' '0']
# Processed Data (3 buckets)/Test/Over_High (276).png
# ['159' '125' '131' ... '71' '122' '0']
# Processed Data (3 buckets)/Test/Over_High (277).png
# ['136' '103' '112' ... '64' '113' '0']
# Processed Data (3 buckets)/Test/Over_High (279).png
# ['166' '126' '128' ... '69' '120' '0']
# Processed Data (3 buckets)/Test/Over_High (281).png
# ['139' '104' '119' ... '71' '120' '0']
# Processed Data (3 buckets)/Test/Over_High (286).png
# ['124' '92' '124' ... '67' '132' '0']
# Processed Data (3 buckets)/Test/Over_High (288).png
# ['129' '92' '120' ... '65' '129' '0']
# Processed Data (3 buckets)/Test/Over_High (289).png
# ['129' '91' '118' ... '64' '127' '0']
# Processed Data (3 buckets)/Test/Over_High (294).png
# ['154' '125' '167' ... '63' '154' '0']
# Processed Data (3 buckets)/Test/Over_High (296).png
# ['96' '62' '101' ... '62' '112' '0']
# Processed Data (3 buckets)/Test/Over_High (297).png
# ['113' '79' '111' ... '67' '122' '0']
# Processed Data (3 buckets)/Test/Over_High (298).png
# ['116' '85' '122' ... '67' '133' '0']
# Processed Data (3 buckets)/Test/Over_High (3).png
# ['126' '88' '117' ... '64' '126' '0']
# Processed Data (3 buckets)/Test/Over_High (307).png
# ['121' '86' '112' ... '65' '122' '0']
# Processed Data (3 buckets)/Test/Over_High (308).png
# ['121' '86' '113' ... '66' '122' '0']
# Processed Data (3 buckets)/Test/Over_High (326).png
# ['162' '128' '128' ... '73' '117' '0']
# Processed Data (3 buckets)/Test/Over_High (329).png
# ['161' '127' '132' ... '69' '118' '0']
# Processed Data (3 buckets)/Test/Over_High (38).png
# ['104' '102' '66' ... '123' '76' '0']
# Processed Data (3 buckets)/Test/Over_High (42).png
# ['144' '123' '139' ... '190' '172' '0']
# Processed Data (3 buckets)/Test/Over_High (43).png
# ['100' '99' '74' ... '87' '56' '0']
# Processed Data (3 buckets)/Test/Over_High (44).png
# ['113' '109' '82' ... '89' '61' '0']
# Processed Data (3 buckets)/Test/Over_High (47).png
# ['108' '104' '73' ... '129' '83' '0']
# Processed Data (3 buckets)/Test/Over_High (62).png
# ['131' '93' '122' ... '71' '129' '0']
# Processed Data (3 buckets)/Test/Over_High (8).png
# ['102' '74' '117' ... '61' '130' '0']
# Processed Data (3 buckets)/Test/Over_High (81).png
# ['130' '121' '116' ... '98' '96' '0']
# Processed Data (3 buckets)/Test/Over_High (85).png
# ['125' '110' '100' ... '95' '89' '0']
# Processed Data (3 buckets)/Test/Over_High (96).png
# ['139' '123' '109' ... '92' '88' '0']
# Processed Data (3 buckets)/Test/Over_High (98).png
# ['141' '125' '111' ... '92' '89' '0']
# Processed Data (3 buckets)/Test/Under_Close (100).png
# ['132' '120' '114' ... '107' '104' '2']
# Processed Data (3 buckets)/Test/Under_Close (101).png
# ['131' '119' '112' ... '110' '105' '2']
# Processed Data (3 buckets)/Test/Under_Close (109).png
# ['82' '79' '48' ... '110' '64' '2']
# Processed Data (3 buckets)/Test/Under_Close (117).png
# ['121' '110' '105' ... '119' '108' '2']
# Processed Data (3 buckets)/Test/Under_Close (118).png
# ['122' '110' '105' ... '118' '108' '2']
# Processed Data (3 buckets)/Test/Under_Close (125).png
# ['111' '101' '95' ... '126' '111' '2']
# Processed Data (3 buckets)/Test/Under_Close (127).png
# ['90' '86' '55' ... '115' '69' '2']
# Processed Data (3 buckets)/Test/Under_Close (130).png
# ['99' '93' '58' ... '112' '66' '2']
# Processed Data (3 buckets)/Test/Under_Close (14).png
# ['126' '115' '109' ... '118' '110' '2']
# Processed Data (3 buckets)/Test/Under_Close (158).png
# ['120' '104' '96' ... '111' '98' '2']
# Processed Data (3 buckets)/Test/Under_Close (172).png
# ['97' '92' '54' ... '110' '62' '2']
# Processed Data (3 buckets)/Test/Under_Close (176).png
# ['120' '104' '97' ... '119' '105' '2']
# Processed Data (3 buckets)/Test/Under_Close (178).png
# ['118' '103' '96' ... '125' '108' '2']
# Processed Data (3 buckets)/Test/Under_Close (182).png
# ['110' '99' '96' ... '126' '111' '2']
# Processed Data (3 buckets)/Test/Under_Close (19).png
# ['95' '93' '59' ... '119' '73' '2']
# Processed Data (3 buckets)/Test/Under_Close (191).png
# ['134' '122' '117' ... '106' '107' '2']
# Processed Data (3 buckets)/Test/Under_Close (193).png
# ['132' '119' '116' ... '109' '108' '2']
# Processed Data (3 buckets)/Test/Under_Close (195).png
# ['131' '119' '117' ... '110' '109' '2']
# Processed Data (3 buckets)/Test/Under_Close (197).png
# ['127' '114' '113' ... '107' '107' '2']
# Processed Data (3 buckets)/Test/Under_Close (2).png
# ['131' '117' '108' ... '111' '103' '2']
# Processed Data (3 buckets)/Test/Under_Close (20).png
# ['131' '118' '118' ... '112' '113' '2']
# Processed Data (3 buckets)/Test/Under_Close (202).png
# ['110' '99' '94' ... '121' '102' '2']
# Processed Data (3 buckets)/Test/Under_Close (204).png
# ['109' '98' '95' ... '121' '103' '2']
# Processed Data (3 buckets)/Test/Under_Close (205).png
# ['112' '101' '96' ... '122' '102' '2']
# Processed Data (3 buckets)/Test/Under_Close (209).png
# ['113' '101' '98' ... '123' '109' '2']
# Processed Data (3 buckets)/Test/Under_Close (210).png
# ['112' '101' '98' ... '125' '110' '2']
# Processed Data (3 buckets)/Test/Under_Close (221).png
# ['118' '107' '107' ... '118' '112' '2']
# Processed Data (3 buckets)/Test/Under_Close (224).png
# ['105' '95' '92' ... '122' '105' '2']
# Processed Data (3 buckets)/Test/Under_Close (228).png
# ['108' '98' '93' ... '120' '102' '2']
# Processed Data (3 buckets)/Test/Under_Close (232).png
# ['89' '85' '52' ... '102' '59' '2']
# Processed Data (3 buckets)/Test/Under_Close (234).png
# ['91' '87' '51' ... '105' '60' '2']
# Processed Data (3 buckets)/Test/Under_Close (235).png
# ['121' '105' '100' ... '109' '100' '2']
# Processed Data (3 buckets)/Test/Under_Close (236).png
# ['122' '107' '102' ... '111' '101' '2']
# Processed Data (3 buckets)/Test/Under_Close (237).png
# ['120' '105' '98' ... '113' '102' '2']
# Processed Data (3 buckets)/Test/Under_Close (238).png
# ['116' '105' '98' ... '115' '100' '2']
# Processed Data (3 buckets)/Test/Under_Close (252).png
# ['115' '104' '101' ... '130' '116' '2']
# Processed Data (3 buckets)/Test/Under_Close (253).png
# ['116' '105' '102' ... '131' '115' '2']
# Processed Data (3 buckets)/Test/Under_Close (255).png
# ['132' '119' '118' ... '109' '110' '2']
# Processed Data (3 buckets)/Test/Under_Close (258).png
# ['130' '114' '108' ... '108' '101' '2']
# Processed Data (3 buckets)/Test/Under_Close (259).png
# ['113' '102' '100' ... '116' '107' '2']
# Processed Data (3 buckets)/Test/Under_Close (271).png
# ['163' '132' '112' ... '86' '99' '2']
# Processed Data (3 buckets)/Test/Under_Close (274).png
# ['131' '100' '109' ... '54' '104' '2']
# Processed Data (3 buckets)/Test/Under_Close (275).png
# ['146' '116' '132' ... '60' '123' '2']
# Processed Data (3 buckets)/Test/Under_Close (283).png
# ['188' '156' '144' ... '72' '117' '2']
# Processed Data (3 buckets)/Test/Under_Close (285).png
# ['164' '136' '135' ... '67' '112' '2']
# Processed Data (3 buckets)/Test/Under_Close (289).png
# ['188' '148' '144' ... '79' '124' '2']
# Processed Data (3 buckets)/Test/Under_Close (294).png
# ['148' '116' '126' ... '70' '115' '2']
# Processed Data (3 buckets)/Test/Under_Close (298).png
# ['145' '109' '123' ... '78' '123' '2']
# Processed Data (3 buckets)/Test/Under_Close (3).png
# ['122' '108' '99' ... '118' '105' '2']
# Processed Data (3 buckets)/Test/Under_Close (304).png
# ['246' '170' '110' ... '99' '106' '2']
# Processed Data (3 buckets)/Test/Under_Close (305).png
# ['163' '136' '119' ... '67' '97' '2']
# Processed Data (3 buckets)/Test/Under_Close (306).png
# ['131' '118' '112' ... '133' '119' '2']
# Processed Data (3 buckets)/Test/Under_Close (310).png
# ['127' '114' '104' ... '127' '111' '2']
# Processed Data (3 buckets)/Test/Under_Close (35).png
# ['107' '98' '93' ... '122' '105' '2']
# Processed Data (3 buckets)/Test/Under_Close (38).png
# ['130' '113' '109' ... '107' '102' '2']
# Processed Data (3 buckets)/Test/Under_Close (4).png
# ['95' '92' '56' ... '114' '66' '2']
# Processed Data (3 buckets)/Test/Under_Close (40).png
# ['115' '105' '101' ... '127' '114' '2']
# Processed Data (3 buckets)/Test/Under_Close (44).png
# ['158' '131' '115' ... '58' '90' '2']
# Processed Data (3 buckets)/Test/Under_Close (50).png
# ['134' '101' '106' ... '69' '104' '2']
# Processed Data (3 buckets)/Test/Under_Close (54).png
# ['99' '93' '53' ... '112' '58' '2']
# Processed Data (3 buckets)/Test/Under_Close (64).png
# ['145' '134' '134' ... '119' '118' '2']
# Processed Data (3 buckets)/Test/Under_Close (66).png
# ['133' '119' '115' ... '112' '106' '2']
# Processed Data (3 buckets)/Test/Under_Close (69).png
# ['115' '103' '98' ... '130' '112' '2']
# Processed Data (3 buckets)/Test/Under_Close (87).png
# ['124' '107' '97' ... '120' '103' '2']
# Processed Data (3 buckets)/Test/Under_Close (92).png
# ['91' '86' '52' ... '117' '67' '2']
# Processed Data (3 buckets)/Test/Under_Close (98).png
# ['122' '109' '102' ... '135' '115' '2']
# Processed Data (3 buckets)/Test/Under_Low (10).png
# ['137' '121' '140' ... '118' '130' '2']
# Processed Data (3 buckets)/Test/Under_Low (102).png
# ['76' '57' '109' ... '117' '144' '2']
# Processed Data (3 buckets)/Test/Under_Low (104).png
# ['90' '81' '96' ... '111' '111' '2']
# Processed Data (3 buckets)/Test/Under_Low (111).png
# ['131' '118' '125' ... '102' '106' '2']
# Processed Data (3 buckets)/Test/Under_Low (112).png
# ['141' '123' '119' ... '94' '97' '2']
# Processed Data (3 buckets)/Test/Under_Low (121).png
# ['141' '123' '125' ... '92' '99' '2']
# Processed Data (3 buckets)/Test/Under_Low (122).png
# ['145' '127' '127' ... '92' '99' '2']
# Processed Data (3 buckets)/Test/Under_Low (124).png
# ['145' '127' '127' ... '94' '103' '2']
# Processed Data (3 buckets)/Test/Under_Low (130).png
# ['146' '126' '123' ... '94' '99' '2']
# Processed Data (3 buckets)/Test/Under_Low (131).png
# ['143' '124' '123' ... '94' '100' '2']
# Processed Data (3 buckets)/Test/Under_Low (135).png
# ['136' '119' '121' ... '99' '105' '2']
# Processed Data (3 buckets)/Test/Under_Low (147).png
# ['136' '119' '118' ... '87' '93' '2']
# Processed Data (3 buckets)/Test/Under_Low (154).png
# ['140' '121' '118' ... '92' '100' '2']
# Processed Data (3 buckets)/Test/Under_Low (166).png
# ['129' '111' '116' ... '88' '99' '2']
# Processed Data (3 buckets)/Test/Under_Low (170).png
# ['125' '108' '113' ... '88' '97' '2']
# Processed Data (3 buckets)/Test/Under_Low (172).png
# ['140' '117' '132' ... '116' '129' '2']
# Processed Data (3 buckets)/Test/Under_Low (180).png
# ['115' '97' '102' ... '117' '110' '2']
# Processed Data (3 buckets)/Test/Under_Low (182).png
# ['117' '99' '105' ... '126' '115' '2']
# Processed Data (3 buckets)/Test/Under_Low (206).png
# ['109' '97' '104' ... '122' '113' '2']
# Processed Data (3 buckets)/Test/Under_Low (210).png
# ['135' '118' '147' ... '119' '142' '2']
# Processed Data (3 buckets)/Test/Under_Low (212).png
# ['143' '126' '145' ... '109' '128' '2']
# Processed Data (3 buckets)/Test/Under_Low (213).png
# ['148' '130' '148' ... '108' '129' '2']
# Processed Data (3 buckets)/Test/Under_Low (225).png
# ['140' '122' '116' ... '92' '97' '2']
# Processed Data (3 buckets)/Test/Under_Low (228).png
# ['126' '111' '108' ... '92' '95' '2']
# Processed Data (3 buckets)/Test/Under_Low (229).png
# ['127' '111' '109' ... '90' '94' '2']
# Processed Data (3 buckets)/Test/Under_Low (24).png
# ['130' '113' '112' ... '93' '97' '2']
# Processed Data (3 buckets)/Test/Under_Low (240).png
# ['113' '99' '99' ... '108' '100' '2']
# Processed Data (3 buckets)/Test/Under_Low (244).png
# ['108' '98' '101' ... '105' '105' '2']
# Processed Data (3 buckets)/Test/Under_Low (264).png
# ['130' '117' '119' ... '97' '97' '2']
# Processed Data (3 buckets)/Test/Under_Low (265).png
# ['121' '109' '112' ... '91' '93' '2']
# Processed Data (3 buckets)/Test/Under_Low (267).png
# ['129' '117' '113' ... '103' '101' '2']
# Processed Data (3 buckets)/Test/Under_Low (270).png
# ['126' '113' '111' ... '105' '100' '2']
# Processed Data (3 buckets)/Test/Under_Low (273).png
# ['123' '111' '110' ... '111' '102' '2']
# Processed Data (3 buckets)/Test/Under_Low (274).png
# ['124' '111' '112' ... '109' '103' '2']
# Processed Data (3 buckets)/Test/Under_Low (276).png
# ['122' '110' '110' ... '111' '103' '2']
# Processed Data (3 buckets)/Test/Under_Low (277).png
# ['120' '108' '108' ... '113' '104' '2']
# Processed Data (3 buckets)/Test/Under_Low (279).png
# ['108' '97' '100' ... '133' '118' '2']
# Processed Data (3 buckets)/Test/Under_Low (281).png
# ['105' '94' '97' ... '130' '114' '2']
# Processed Data (3 buckets)/Test/Under_Low (286).png
# ['107' '96' '98' ... '125' '110' '2']
# Processed Data (3 buckets)/Test/Under_Low (288).png
# ['107' '96' '93' ... '117' '104' '2']
# Processed Data (3 buckets)/Test/Under_Low (289).png
# ['108' '97' '96' ... '118' '105' '2']
# Processed Data (3 buckets)/Test/Under_Low (294).png
# ['159' '127' '129' ... '70' '122' '2']
# Processed Data (3 buckets)/Test/Under_Low (296).png
# ['162' '128' '131' ... '67' '121' '2']
# Processed Data (3 buckets)/Test/Under_Low (297).png
# ['167' '131' '133' ... '66' '123' '2']
# Processed Data (3 buckets)/Test/Under_Low (298).png
# ['167' '131' '134' ... '67' '121' '2']
# Processed Data (3 buckets)/Test/Under_Low (3).png
# ['157' '119' '139' ... '81' '139' '2']
# Processed Data (3 buckets)/Test/Under_Low (307).png
# ['166' '124' '137' ... '77' '137' '2']
# Processed Data (3 buckets)/Test/Under_Low (308).png
# ['152' '113' '135' ... '78' '137' '2']
# Processed Data (3 buckets)/Test/Under_Low (326).png
# ['137' '125' '126' ... '97' '103' '2']
# Processed Data (3 buckets)/Test/Under_Low (329).png
# ['137' '117' '113' ... '93' '98' '2']
# Processed Data (3 buckets)/Test/Under_Low (38).png
# ['140' '118' '136' ... '98' '120' '2']
# Processed Data (3 buckets)/Test/Under_Low (42).png
# ['113' '94' '130' ... '133' '150' '2']
# Processed Data (3 buckets)/Test/Under_Low (43).png
# ['121' '102' '134' ... '133' '150' '2']
# Processed Data (3 buckets)/Test/Under_Low (44).png
# ['135' '119' '125' ... '88' '100' '2']
# Processed Data (3 buckets)/Test/Under_Low (47).png
# ['111' '101' '107' ... '117' '113' '2']
# Processed Data (3 buckets)/Test/Under_Low (62).png
# ['146' '131' '128' ... '105' '108' '2']
# Processed Data (3 buckets)/Test/Under_Low (8).png
# ['145' '113' '124' ... '71' '117' '2']
# Processed Data (3 buckets)/Test/Under_Low (81).png
# ['138' '121' '120' ... '90' '96' '2']
# Processed Data (3 buckets)/Test/Under_Low (85).png
# ['143' '125' '122' ... '91' '96' '2']
# Processed Data (3 buckets)/Test/Under_Low (96).png
# ['105' '96' '99' ... '117' '108' '2']
# Processed Data (3 buckets)/Test/Under_Low (98).png
# ['104' '94' '94' ... '108' '97' '2']
# Processed Data (3 buckets)/Training/
# Processed Data (3 buckets)/Training/Good (1).png
# ['94' '92' '61' ... '128' '77' '1']
# Processed Data (3 buckets)/Training/Good (10).png
# ['138' '106' '120' ... '63' '119' '1']
# Processed Data (3 buckets)/Training/Good (102).png
# ['137' '96' '125' ... '65' '130' '1']
# Processed Data (3 buckets)/Training/Good (103).png
# ['153' '113' '130' ... '67' '132' '1']
# Processed Data (3 buckets)/Training/Good (104).png
# ['161' '119' '134' ... '68' '134' '1']
# Processed Data (3 buckets)/Training/Good (106).png
# ['148' '110' '132' ... '65' '131' '1']
# Processed Data (3 buckets)/Training/Good (107).png
# ['155' '115' '126' ... '68' '129' '1']
# Processed Data (3 buckets)/Training/Good (108).png
# ['185' '135' '139' ... '71' '134' '1']
# Processed Data (3 buckets)/Training/Good (109).png
# ['202' '148' '144' ... '74' '134' '1']
# Processed Data (3 buckets)/Training/Good (110).png
# ['187' '145' '133' ... '68' '123' '1']
# Processed Data (3 buckets)/Training/Good (111).png
# ['199' '152' '138' ... '72' '123' '1']
# Processed Data (3 buckets)/Training/Good (112).png
# ['203' '155' '137' ... '71' '122' '1']
# Processed Data (3 buckets)/Training/Good (113).png
# ['193' '148' '138' ... '65' '122' '1']
# Processed Data (3 buckets)/Training/Good (114).png
# ['194' '148' '141' ... '66' '123' '1']
# Processed Data (3 buckets)/Training/Good (115).png
# ['194' '148' '140' ... '66' '124' '1']
# Processed Data (3 buckets)/Training/Good (116).png
# ['197' '151' '141' ... '70' '124' '1']
# Processed Data (3 buckets)/Training/Good (117).png
# ['203' '154' '142' ... '74' '126' '1']
# Processed Data (3 buckets)/Training/Good (12).png
# ['122' '100' '117' ... '95' '125' '1']
# Processed Data (3 buckets)/Training/Good (120).png
# ['154' '108' '124' ... '69' '128' '1']
# Processed Data (3 buckets)/Training/Good (121).png
# ['159' '112' '124' ... '69' '129' '1']
# Processed Data (3 buckets)/Training/Good (122).png
# ['132' '103' '129' ... '83' '133' '1']
# Processed Data (3 buckets)/Training/Good (123).png
# ['132' '102' '127' ... '77' '129' '1']
# Processed Data (3 buckets)/Training/Good (124).png
# ['111' '85' '118' ... '66' '122' '1']
# Processed Data (3 buckets)/Training/Good (125).png
# ['161' '118' '137' ... '69' '138' '1']
# Processed Data (3 buckets)/Training/Good (128).png
# ['113' '79' '112' ... '62' '122' '1']
# Processed Data (3 buckets)/Training/Good (13).png
# ['106' '89' '88' ... '52' '76' '1']
# Processed Data (3 buckets)/Training/Good (130).png
# ['116' '81' '111' ... '61' '121' '1']
# Processed Data (3 buckets)/Training/Good (131).png
# ['119' '83' '111' ... '62' '120' '1']
# Processed Data (3 buckets)/Training/Good (133).png
# ['124' '87' '113' ... '63' '123' '1']
# Processed Data (3 buckets)/Training/Good (134).png
# ['143' '99' '116' ... '69' '123' '1']
# Processed Data (3 buckets)/Training/Good (135).png
# ['130' '94' '124' ... '66' '131' '1']
# Processed Data (3 buckets)/Training/Good (136).png
# ['125' '84' '105' ... '62' '114' '1']
# Processed Data (3 buckets)/Training/Good (137).png
# ['121' '79' '104' ... '60' '115' '1']
# Processed Data (3 buckets)/Training/Good (138).png
# ['122' '82' '108' ... '61' '117' '1']
# Processed Data (3 buckets)/Training/Good (139).png
# ['123' '82' '106' ... '61' '116' '1']
# Processed Data (3 buckets)/Training/Good (14).png
# ['137' '111' '99' ... '57' '81' '1']
# Processed Data (3 buckets)/Training/Good (140).png
# ['208' '152' '149' ... '74' '138' '1']
# Processed Data (3 buckets)/Training/Good (142).png
# ['214' '163' '142' ... '67' '125' '1']
# Processed Data (3 buckets)/Training/Good (143).png
# ['146' '115' '135' ... '64' '129' '1']
# Processed Data (3 buckets)/Training/Good (144).png
# ['138' '109' '131' ... '64' '128' '1']
# Processed Data (3 buckets)/Training/Good (145).png
# ['162' '114' '116' ... '67' '117' '1']
# Processed Data (3 buckets)/Training/Good (146).png
# ['160' '121' '131' ... '70' '128' '1']
# Processed Data (3 buckets)/Training/Good (147).png
# ['156' '113' '127' ... '70' '129' '1']
# Processed Data (3 buckets)/Training/Good (148).png
# ['134' '100' '124' ... '72' '129' '1']
# Processed Data (3 buckets)/Training/Good (149).png
# ['118' '89' '119' ... '69' '127' '1']
# Processed Data (3 buckets)/Training/Good (15).png
# ['135' '109' '106' ... '51' '88' '1']
# Processed Data (3 buckets)/Training/Good (150).png
# ['141' '106' '124' ... '68' '127' '1']
# Processed Data (3 buckets)/Training/Good (151).png
# ['169' '128' '135' ... '70' '128' '1']
# Processed Data (3 buckets)/Training/Good (152).png
# ['170' '129' '129' ... '66' '120' '1']
# Processed Data (3 buckets)/Training/Good (153).png
# ['170' '133' '139' ... '67' '125' '1']
# Processed Data (3 buckets)/Training/Good (154).png
# ['170' '130' '128' ... '64' '115' '1']
# Processed Data (3 buckets)/Training/Good (155).png
# ['167' '133' '132' ... '66' '121' '1']
# Processed Data (3 buckets)/Training/Good (156).png
# ['165' '139' '116' ... '64' '81' '1']
# Processed Data (3 buckets)/Training/Good (157).png
# ['80' '59' '96' ... '48' '106' '1']
# Processed Data (3 buckets)/Training/Good (158).png
# ['151' '120' '103' ... '55' '86' '1']
# Processed Data (3 buckets)/Training/Good (159).png
# ['165' '131' '128' ... '63' '107' '1']
# Processed Data (3 buckets)/Training/Good (160).png
# ['164' '130' '124' ... '63' '108' '1']
# Processed Data (3 buckets)/Training/Good (161).png
# ['93' '85' '100' ... '110' '112' '1']
# Processed Data (3 buckets)/Training/Good (163).png
# ['112' '103' '117' ... '114' '118' '1']
# Processed Data (3 buckets)/Training/Good (164).png
# ['123' '114' '123' ... '118' '119' '1']
# Processed Data (3 buckets)/Training/Good (165).png
# ['125' '112' '115' ... '117' '111' '1']
# Processed Data (3 buckets)/Training/Good (166).png
# ['132' '117' '118' ... '118' '110' '1']
# Processed Data (3 buckets)/Training/Good (167).png
# ['136' '120' '120' ... '118' '110' '1']
# Processed Data (3 buckets)/Training/Good (168).png
# ['142' '125' '123' ... '117' '109' '1']
# Processed Data (3 buckets)/Training/Good (169).png
# ['145' '128' '124' ... '116' '108' '1']
# Processed Data (3 buckets)/Training/Good (17).png
# ['166' '128' '131' ... '62' '118' '1']
# Processed Data (3 buckets)/Training/Good (170).png
# ['127' '116' '115' ... '106' '99' '1']
# Processed Data (3 buckets)/Training/Good (171).png
# ['127' '116' '116' ... '104' '99' '1']
# Processed Data (3 buckets)/Training/Good (172).png
# ['130' '118' '116' ... '104' '98' '1']
# Processed Data (3 buckets)/Training/Good (173).png
# ['134' '121' '118' ... '104' '99' '1']
# Processed Data (3 buckets)/Training/Good (174).png
# ['135' '123' '118' ... '104' '96' '1']
# Processed Data (3 buckets)/Training/Good (176).png
# ['130' '118' '116' ... '99' '97' '1']
# Processed Data (3 buckets)/Training/Good (177).png
# ['131' '120' '117' ... '97' '98' '1']
# Processed Data (3 buckets)/Training/Good (178).png
# ['131' '120' '116' ... '97' '96' '1']
# Processed Data (3 buckets)/Training/Good (18).png
# ['138' '104' '116' ... '63' '115' '1']
# Processed Data (3 buckets)/Training/Good (181).png
# ['124' '113' '108' ... '93' '93' '1']
# Processed Data (3 buckets)/Training/Good (182).png
# ['125' '114' '110' ... '93' '93' '1']
# Processed Data (3 buckets)/Training/Good (183).png
# ['124' '113' '108' ... '94' '95' '1']
# Processed Data (3 buckets)/Training/Good (184).png
# ['129' '112' '101' ... '93' '86' '1']
# Processed Data (3 buckets)/Training/Good (186).png
# ['148' '115' '129' ... '89' '124' '1']
# Processed Data (3 buckets)/Training/Good (187).png
# ['147' '114' '126' ... '91' '125' '1']
# Processed Data (3 buckets)/Training/Good (188).png
# ['142' '111' '127' ... '92' '124' '1']
# Processed Data (3 buckets)/Training/Good (189).png
# ['138' '108' '125' ... '93' '123' '1']
# Processed Data (3 buckets)/Training/Good (19).png
# ['202' '157' '142' ... '70' '124' '1']
# Processed Data (3 buckets)/Training/Good (190).png
# ['142' '110' '127' ... '93' '125' '1']
# Processed Data (3 buckets)/Training/Good (191).png
# ['143' '112' '124' ... '97' '124' '1']
# Processed Data (3 buckets)/Training/Good (193).png
# ['123' '94' '117' ... '87' '120' '1']
# Processed Data (3 buckets)/Training/Good (195).png
# ['122' '93' '118' ... '92' '124' '1']
# Processed Data (3 buckets)/Training/Good (197).png
# ['121' '92' '117' ... '96' '124' '1']
# Processed Data (3 buckets)/Training/Good (199).png
# ['123' '94' '120' ... '98' '127' '1']
# Processed Data (3 buckets)/Training/Good (20).png
# ['212' '170' '157' ... '73' '126' '1']
# Processed Data (3 buckets)/Training/Good (200).png
# ['122' '94' '118' ... '100' '128' '1']
# Processed Data (3 buckets)/Training/Good (203).png
# ['118' '90' '117' ... '101' '128' '1']
# Processed Data (3 buckets)/Training/Good (204).png
# ['119' '91' '119' ... '101' '128' '1']
# Processed Data (3 buckets)/Training/Good (206).png
# ['118' '90' '116' ... '98' '127' '1']
# Processed Data (3 buckets)/Training/Good (209).png
# ['118' '90' '114' ... '97' '123' '1']
# Processed Data (3 buckets)/Training/Good (21).png
# ['116' '96' '96' ... '70' '95' '1']
# Processed Data (3 buckets)/Training/Good (210).png
# ['119' '90' '113' ... '101' '122' '1']
# Processed Data (3 buckets)/Training/Good (212).png
# ['120' '90' '114' ... '102' '123' '1']
# Processed Data (3 buckets)/Training/Good (214).png
# ['120' '92' '119' ... '101' '129' '1']
# Processed Data (3 buckets)/Training/Good (215).png
# ['122' '93' '120' ... '106' '128' '1']
# Processed Data (3 buckets)/Training/Good (216).png
# ['125' '95' '122' ... '108' '133' '1']
# Processed Data (3 buckets)/Training/Good (217).png
# ['124' '95' '121' ... '110' '133' '1']
# Processed Data (3 buckets)/Training/Good (218).png
# ['120' '95' '124' ... '110' '135' '1']
# Processed Data (3 buckets)/Training/Good (219).png
# ['118' '94' '124' ... '107' '132' '1']
# Processed Data (3 buckets)/Training/Good (22).png
# ['126' '105' '101' ... '64' '93' '1']
# Processed Data (3 buckets)/Training/Good (220).png
# ['119' '95' '125' ... '107' '132' '1']
# Processed Data (3 buckets)/Training/Good (221).png
# ['120' '95' '126' ... '103' '133' '1']
# Processed Data (3 buckets)/Training/Good (222).png
# ['117' '93' '123' ... '99' '131' '1']
# Processed Data (3 buckets)/Training/Good (223).png
# ['124' '95' '122' ... '98' '127' '1']
# Processed Data (3 buckets)/Training/Good (226).png
# ['136' '106' '126' ... '101' '129' '1']
# Processed Data (3 buckets)/Training/Good (227).png
# ['136' '106' '126' ... '100' '128' '1']
# Processed Data (3 buckets)/Training/Good (229).png
# ['128' '103' '126' ... '95' '128' '1']
# Processed Data (3 buckets)/Training/Good (23).png
# ['123' '101' '122' ... '68' '117' '1']
# Processed Data (3 buckets)/Training/Good (230).png
# ['129' '104' '125' ... '97' '130' '1']
# Processed Data (3 buckets)/Training/Good (232).png
# ['130' '105' '126' ... '100' '131' '1']
# Processed Data (3 buckets)/Training/Good (233).png
# ['95' '70' '122' ... '95' '133' '1']
# Processed Data (3 buckets)/Training/Good (234).png
# ['100' '76' '121' ... '93' '131' '1']
# Processed Data (3 buckets)/Training/Good (235).png
# ['109' '83' '124' ... '94' '134' '1']
# Processed Data (3 buckets)/Training/Good (237).png
# ['106' '79' '120' ... '84' '129' '1']
# Processed Data (3 buckets)/Training/Good (242).png
# ['155' '91' '72' ... '76' '78' '1']
# Processed Data (3 buckets)/Training/Good (243).png
# ['161' '96' '72' ... '82' '77' '1']
# Processed Data (3 buckets)/Training/Good (244).png
# ['156' '99' '88' ... '84' '93' '1']
# Processed Data (3 buckets)/Training/Good (246).png
# ['161' '101' '88' ... '82' '92' '1']
# Processed Data (3 buckets)/Training/Good (247).png
# ['162' '101' '89' ... '82' '93' '1']
# Processed Data (3 buckets)/Training/Good (248).png
# ['161' '101' '89' ... '83' '93' '1']
# Processed Data (3 buckets)/Training/Good (249).png
# ['150' '101' '106' ... '82' '112' '1']
# Processed Data (3 buckets)/Training/Good (25).png
# ['153' '120' '133' ... '76' '126' '1']
# Processed Data (3 buckets)/Training/Good (250).png
# ['150' '101' '107' ... '83' '110' '1']
# Processed Data (3 buckets)/Training/Good (251).png
# ['149' '102' '104' ... '84' '110' '1']
# Processed Data (3 buckets)/Training/Good (252).png
# ['149' '101' '106' ... '86' '109' '1']
# Processed Data (3 buckets)/Training/Good (253).png
# ['150' '102' '105' ... '85' '109' '1']
# Processed Data (3 buckets)/Training/Good (254).png
# ['142' '104' '124' ... '86' '125' '1']
# Processed Data (3 buckets)/Training/Good (255).png
# ['142' '103' '124' ... '87' '127' '1']
# Processed Data (3 buckets)/Training/Good (256).png
# ['143' '105' '124' ... '88' '126' '1']
# Processed Data (3 buckets)/Training/Good (259).png
# ['138' '105' '125' ... '88' '129' '1']
# Processed Data (3 buckets)/Training/Good (261).png
# ['138' '105' '129' ... '90' '132' '1']
# Processed Data (3 buckets)/Training/Good (262).png
# ['138' '104' '128' ... '90' '131' '1']
# Processed Data (3 buckets)/Training/Good (265).png
# ['143' '108' '135' ... '89' '138' '1']
# Processed Data (3 buckets)/Training/Good (266).png
# ['143' '107' '134' ... '89' '136' '1']
# Processed Data (3 buckets)/Training/Good (267).png
# ['144' '108' '133' ... '89' '135' '1']
# Processed Data (3 buckets)/Training/Good (268).png
# ['145' '108' '132' ... '88' '136' '1']
# Processed Data (3 buckets)/Training/Good (269).png
# ['142' '106' '131' ... '88' '135' '1']
# Processed Data (3 buckets)/Training/Good (27).png
# ['152' '120' '127' ... '76' '118' '1']
# Processed Data (3 buckets)/Training/Good (270).png
# ['142' '106' '134' ... '89' '135' '1']
# Processed Data (3 buckets)/Training/Good (271).png
# ['144' '108' '134' ... '89' '135' '1']
# Processed Data (3 buckets)/Training/Good (272).png
# ['145' '109' '134' ... '88' '137' '1']
# Processed Data (3 buckets)/Training/Good (273).png
# ['144' '108' '133' ... '88' '136' '1']
# Processed Data (3 buckets)/Training/Good (274).png
# ['144' '108' '136' ... '90' '138' '1']
# ...
# ['110' '97' '106' ... '122' '115' '2']
# Processed Data (3 buckets)/Training/Under_Low (205).png
# ['109' '97' '106' ... '119' '116' '2']
# Processed Data (3 buckets)/Training/Under_Low (207).png
# ['109' '97' '104' ... '122' '114' '2']
# Processed Data (3 buckets)/Training/Under_Low (208).png
# ['117' '103' '134' ... '121' '141' '2']
# Processed Data (3 buckets)/Training/Under_Low (209).png
# ['124' '109' '139' ... '120' '142' '2']
# Processed Data (3 buckets)/Training/Under_Low (21).png
# ['86' '68' '115' ... '120' '142' '2']
# Processed Data (3 buckets)/Training/Under_Low (211).png
# ['146' '129' '153' ... '120' '142' '2']
# Processed Data (3 buckets)/Training/Under_Low (214).png
# ['150' '132' '149' ... '108' '128' '2']
# Processed Data (3 buckets)/Training/Under_Low (215).png
# ['153' '135' '151' ... '108' '127' '2']
# Processed Data (3 buckets)/Training/Under_Low (216).png
# ['132' '118' '120' ... '90' '96' '2']
# Processed Data (3 buckets)/Training/Under_Low (217).png
# ['133' '118' '121' ... '89' '96' '2']
# Processed Data (3 buckets)/Training/Under_Low (218).png
# ['134' '120' '119' ... '89' '97' '2']
# Processed Data (3 buckets)/Training/Under_Low (219).png
# ['134' '120' '120' ... '89' '96' '2']
# Processed Data (3 buckets)/Training/Under_Low (22).png
# ['127' '112' '113' ... '64' '83' '2']
# Processed Data (3 buckets)/Training/Under_Low (220).png
# ['142' '124' '123' ... '93' '102' '2']
# Processed Data (3 buckets)/Training/Under_Low (221).png
# ['143' '124' '126' ... '92' '102' '2']
# Processed Data (3 buckets)/Training/Under_Low (222).png
# ['141' '124' '121' ... '91' '101' '2']
# Processed Data (3 buckets)/Training/Under_Low (223).png
# ['140' '122' '122' ... '92' '99' '2']
# Processed Data (3 buckets)/Training/Under_Low (224).png
# ['140' '123' '117' ... '92' '96' '2']
# Processed Data (3 buckets)/Training/Under_Low (226).png
# ['137' '119' '114' ... '92' '97' '2']
# Processed Data (3 buckets)/Training/Under_Low (227).png
# ['136' '119' '116' ... '93' '96' '2']
# Processed Data (3 buckets)/Training/Under_Low (23).png
# ['142' '124' '122' ... '92' '95' '2']
# Processed Data (3 buckets)/Training/Under_Low (230).png
# ['125' '110' '106' ... '92' '94' '2']
# Processed Data (3 buckets)/Training/Under_Low (231).png
# ['123' '108' '106' ... '93' '95' '2']
# Processed Data (3 buckets)/Training/Under_Low (232).png
# ['121' '106' '104' ... '92' '96' '2']
# Processed Data (3 buckets)/Training/Under_Low (233).png
# ['120' '105' '103' ... '95' '96' '2']
# Processed Data (3 buckets)/Training/Under_Low (234).png
# ['119' '105' '105' ... '98' '96' '2']
# Processed Data (3 buckets)/Training/Under_Low (235).png
# ['118' '103' '103' ... '101' '98' '2']
# Processed Data (3 buckets)/Training/Under_Low (236).png
# ['118' '103' '103' ... '102' '101' '2']
# Processed Data (3 buckets)/Training/Under_Low (237).png
# ['117' '102' '102' ... '106' '102' '2']
# Processed Data (3 buckets)/Training/Under_Low (238).png
# ['115' '101' '100' ... '110' '101' '2']
# Processed Data (3 buckets)/Training/Under_Low (239).png
# ['115' '100' '100' ... '111' '102' '2']
# Processed Data (3 buckets)/Training/Under_Low (241).png
# ['115' '100' '99' ... '111' '102' '2']
# Processed Data (3 buckets)/Training/Under_Low (242).png
# ['116' '100' '105' ... '112' '108' '2']
# Processed Data (3 buckets)/Training/Under_Low (243).png
# ['113' '103' '108' ... '115' '114' '2']
# Processed Data (3 buckets)/Training/Under_Low (245).png
# ['111' '100' '104' ... '106' '108' '2']
# Processed Data (3 buckets)/Training/Under_Low (246).png
# ['112' '101' '104' ... '110' '108' '2']
# Processed Data (3 buckets)/Training/Under_Low (247).png
# ['113' '102' '104' ... '108' '106' '2']
# Processed Data (3 buckets)/Training/Under_Low (248).png
# ['90' '86' '108' ... '202' '209' '2']
# Processed Data (3 buckets)/Training/Under_Low (249).png
# ['99' '95' '113' ... '198' '203' '2']
# Processed Data (3 buckets)/Training/Under_Low (25).png
# ['145' '127' '123' ... '95' '99' '2']
# Processed Data (3 buckets)/Training/Under_Low (250).png
# ['121' '115' '128' ... '205' '206' '2']
# Processed Data (3 buckets)/Training/Under_Low (251).png
# ['105' '100' '108' ... '171' '171' '2']
# Processed Data (3 buckets)/Training/Under_Low (252).png
# ['117' '110' '117' ... '179' '179' '2']
# Processed Data (3 buckets)/Training/Under_Low (253).png
# ['106' '101' '109' ... '179' '181' '2']
# Processed Data (3 buckets)/Training/Under_Low (254).png
# ['118' '112' '117' ... '203' '209' '2']
# Processed Data (3 buckets)/Training/Under_Low (255).png
# ['87' '85' '65' ... '152' '134' '2']
# Processed Data (3 buckets)/Training/Under_Low (256).png
# ['94' '92' '66' ... '168' '149' '2']
# Processed Data (3 buckets)/Training/Under_Low (257).png
# ['89' '83' '49' ... '80' '40' '2']
# Processed Data (3 buckets)/Training/Under_Low (258).png
# ['104' '101' '68' ... '94' '55' '2']
# Processed Data (3 buckets)/Training/Under_Low (259).png
# ['105' '102' '67' ... '93' '54' '2']
# Processed Data (3 buckets)/Training/Under_Low (26).png
# ['143' '124' '125' ... '95' '103' '2']
# Processed Data (3 buckets)/Training/Under_Low (260).png
# ['106' '102' '69' ... '85' '51' '2']
# Processed Data (3 buckets)/Training/Under_Low (261).png
# ['138' '125' '125' ... '109' '105' '2']
# Processed Data (3 buckets)/Training/Under_Low (262).png
# ['141' '127' '126' ... '108' '107' '2']
# Processed Data (3 buckets)/Training/Under_Low (263).png
# ['141' '127' '125' ... '108' '106' '2']
# Processed Data (3 buckets)/Training/Under_Low (266).png
# ['121' '109' '109' ... '87' '87' '2']
# Processed Data (3 buckets)/Training/Under_Low (268).png
# ['126' '115' '113' ... '105' '101' '2']
# Processed Data (3 buckets)/Training/Under_Low (269).png
# ['126' '114' '111' ... '104' '98' '2']
# Processed Data (3 buckets)/Training/Under_Low (27).png
# ['98' '82' '88' ... '87' '90' '2']
# Processed Data (3 buckets)/Training/Under_Low (271).png
# ['123' '112' '110' ... '107' '103' '2']
# Processed Data (3 buckets)/Training/Under_Low (272).png
# ['123' '113' '112' ... '108' '102' '2']
# Processed Data (3 buckets)/Training/Under_Low (275).png
# ['122' '110' '109' ... '110' '104' '2']
# Processed Data (3 buckets)/Training/Under_Low (278).png
# ['119' '108' '107' ... '114' '104' '2']
# Processed Data (3 buckets)/Training/Under_Low (28).png
# ['132' '114' '113' ... '96' '98' '2']
# Processed Data (3 buckets)/Training/Under_Low (280).png
# ['104' '93' '97' ... '129' '113' '2']
# Processed Data (3 buckets)/Training/Under_Low (282).png
# ['103' '93' '95' ... '128' '111' '2']
# Processed Data (3 buckets)/Training/Under_Low (283).png
# ['106' '95' '98' ... '131' '113' '2']
# Processed Data (3 buckets)/Training/Under_Low (284).png
# ['107' '96' '97' ... '129' '112' '2']
# Processed Data (3 buckets)/Training/Under_Low (285).png
# ['104' '93' '95' ... '123' '107' '2']
# Processed Data (3 buckets)/Training/Under_Low (287).png
# ['106' '95' '94' ... '118' '105' '2']
# Processed Data (3 buckets)/Training/Under_Low (29).png
# ['129' '111' '111' ... '103' '102' '2']
# Processed Data (3 buckets)/Training/Under_Low (290).png
# ['108' '97' '93' ... '117' '102' '2']
# Processed Data (3 buckets)/Training/Under_Low (291).png
# ['158' '124' '129' ... '70' '122' '2']
# Processed Data (3 buckets)/Training/Under_Low (292).png
# ['161' '125' '135' ... '70' '125' '2']
# Processed Data (3 buckets)/Training/Under_Low (293).png
# ['162' '126' '131' ... '71' '122' '2']
# Processed Data (3 buckets)/Training/Under_Low (295).png
# ['163' '128' '130' ... '68' '121' '2']
# Processed Data (3 buckets)/Training/Under_Low (299).png
# ['139' '103' '118' ... '58' '117' '2']
# Processed Data (3 buckets)/Training/Under_Low (30).png
# ['129' '112' '111' ... '106' '104' '2']
# Processed Data (3 buckets)/Training/Under_Low (300).png
# ['129' '99' '124' ... '76' '126' '2']
# Processed Data (3 buckets)/Training/Under_Low (301).png
# ['138' '107' '130' ... '76' '130' '2']
# Processed Data (3 buckets)/Training/Under_Low (302).png
# ['142' '111' '122' ... '74' '123' '2']
# Processed Data (3 buckets)/Training/Under_Low (303).png
# ['136' '102' '133' ... '81' '141' '2']
# Processed Data (3 buckets)/Training/Under_Low (304).png
# ['145' '121' '106' ... '62' '86' '2']
# Processed Data (3 buckets)/Training/Under_Low (305).png
# ['140' '114' '165' ... '64' '159' '2']
# Processed Data (3 buckets)/Training/Under_Low (306).png
# ['146' '109' '114' ... '64' '114' '2']
# Processed Data (3 buckets)/Training/Under_Low (309).png
# ['140' '104' '135' ... '80' '142' '2']
# Processed Data (3 buckets)/Training/Under_Low (31).png
# ['125' '108' '107' ... '86' '93' '2']
# Processed Data (3 buckets)/Training/Under_Low (310).png
# ['131' '98' '130' ... '81' '142' '2']
# Processed Data (3 buckets)/Training/Under_Low (311).png
# ['138' '104' '135' ... '82' '143' '2']
# Processed Data (3 buckets)/Training/Under_Low (312).png
# ['148' '111' '135' ... '80' '141' '2']
# Processed Data (3 buckets)/Training/Under_Low (313).png
# ['149' '116' '130' ... '72' '128' '2']
# Processed Data (3 buckets)/Training/Under_Low (314).png
# ['157' '123' '133' ... '74' '129' '2']
# Processed Data (3 buckets)/Training/Under_Low (315).png
# ['121' '95' '114' ... '74' '120' '2']
# Processed Data (3 buckets)/Training/Under_Low (316).png
# ['176' '140' '133' ... '73' '118' '2']
# Processed Data (3 buckets)/Training/Under_Low (317).png
# ['148' '113' '117' ... '66' '111' '2']
# Processed Data (3 buckets)/Training/Under_Low (318).png
# ['174' '138' '134' ... '73' '120' '2']
# Processed Data (3 buckets)/Training/Under_Low (319).png
# ['168' '132' '137' ... '71' '122' '2']
# Processed Data (3 buckets)/Training/Under_Low (32).png
# ['126' '108' '112' ... '87' '96' '2']
# Processed Data (3 buckets)/Training/Under_Low (320).png
# ['122' '108' '129' ... '106' '122' '2']
# Processed Data (3 buckets)/Training/Under_Low (321).png
# ['144' '127' '142' ... '118' '129' '2']
# Processed Data (3 buckets)/Training/Under_Low (322).png
# ['126' '113' '115' ... '102' '100' '2']
# Processed Data (3 buckets)/Training/Under_Low (323).png
# ['132' '117' '117' ... '99' '98' '2']
# Processed Data (3 buckets)/Training/Under_Low (324).png
# ['136' '125' '123' ... '98' '97' '2']
# Processed Data (3 buckets)/Training/Under_Low (325).png
# ['136' '125' '126' ... '96' '100' '2']
# Processed Data (3 buckets)/Training/Under_Low (327).png
# ['134' '115' '111' ... '92' '96' '2']
# Processed Data (3 buckets)/Training/Under_Low (328).png
# ['135' '116' '110' ... '94' '95' '2']
# Processed Data (3 buckets)/Training/Under_Low (33).png
# ['132' '110' '129' ... '118' '131' '2']
# Processed Data (3 buckets)/Training/Under_Low (330).png
# ['136' '115' '111' ... '92' '96' '2']
# Processed Data (3 buckets)/Training/Under_Low (34).png
# ['115' '97' '104' ... '121' '114' '2']
# Processed Data (3 buckets)/Training/Under_Low (35).png
# ['101' '90' '97' ... '115' '111' '2']
# Processed Data (3 buckets)/Training/Under_Low (36).png
# ['94' '79' '126' ... '124' '148' '2']
# Processed Data (3 buckets)/Training/Under_Low (37).png
# ['134' '114' '130' ... '95' '115' '2']
# Processed Data (3 buckets)/Training/Under_Low (39).png
# ['136' '114' '133' ... '104' '125' '2']
# Processed Data (3 buckets)/Training/Under_Low (4).png
# ['84' '69' '87' ... '35' '84' '2']
# Processed Data (3 buckets)/Training/Under_Low (40).png
# ['111' '94' '100' ... '119' '112' '2']
# Processed Data (3 buckets)/Training/Under_Low (41).png
# ['115' '102' '112' ... '119' '118' '2']
# Processed Data (3 buckets)/Training/Under_Low (45).png
# ['138' '121' '124' ... '91' '101' '2']
# Processed Data (3 buckets)/Training/Under_Low (46).png
# ['118' '104' '103' ... '100' '97' '2']
# Processed Data (3 buckets)/Training/Under_Low (48).png
# ['89' '81' '106' ... '232' '235' '2']
# Processed Data (3 buckets)/Training/Under_Low (49).png
# ['111' '106' '124' ... '201' '204' '2']
# Processed Data (3 buckets)/Training/Under_Low (5).png
# ['168' '132' '136' ... '73' '129' '2']
# Processed Data (3 buckets)/Training/Under_Low (50).png
# ['112' '105' '109' ... '170' '168' '2']
# Processed Data (3 buckets)/Training/Under_Low (51).png
# ['108' '103' '71' ... '92' '53' '2']
# Processed Data (3 buckets)/Training/Under_Low (52).png
# ['134' '121' '118' ... '103' '99' '2']
# Processed Data (3 buckets)/Training/Under_Low (53).png
# ['120' '109' '108' ... '116' '106' '2']
# Processed Data (3 buckets)/Training/Under_Low (54).png
# ['111' '100' '98' ... '128' '108' '2']
# Processed Data (3 buckets)/Training/Under_Low (55).png
# ['108' '97' '98' ... '123' '110' '2']
# Processed Data (3 buckets)/Training/Under_Low (56).png
# ['138' '118' '114' ... '96' '99' '2']
# Processed Data (3 buckets)/Training/Under_Low (57).png
# ['139' '118' '114' ... '97' '101' '2']
# Processed Data (3 buckets)/Training/Under_Low (58).png
# ['140' '119' '117' ... '98' '102' '2']
# Processed Data (3 buckets)/Training/Under_Low (59).png
# ['154' '132' '123' ... '100' '102' '2']
# Processed Data (3 buckets)/Training/Under_Low (6).png
# ['163' '128' '135' ... '73' '128' '2']
# Processed Data (3 buckets)/Training/Under_Low (60).png
# ['153' '131' '124' ... '101' '105' '2']
# Processed Data (3 buckets)/Training/Under_Low (61).png
# ['150' '135' '131' ... '104' '111' '2']
# Processed Data (3 buckets)/Training/Under_Low (63).png
# ['144' '130' '128' ... '105' '110' '2']
# Processed Data (3 buckets)/Training/Under_Low (64).png
# ['125' '112' '111' ... '125' '114' '2']
# Processed Data (3 buckets)/Training/Under_Low (65).png
# ['126' '113' '114' ... '133' '122' '2']
# Processed Data (3 buckets)/Training/Under_Low (66).png
# ['119' '106' '109' ... '126' '119' '2']
# Processed Data (3 buckets)/Training/Under_Low (67).png
# ['120' '109' '113' ... '129' '122' '2']
# Processed Data (3 buckets)/Training/Under_Low (68).png
# ['120' '109' '113' ... '128' '120' '2']
# Processed Data (3 buckets)/Training/Under_Low (69).png
# ['114' '104' '106' ... '121' '110' '2']
# Processed Data (3 buckets)/Training/Under_Low (7).png
# ['129' '100' '122' ... '78' '124' '2']
# Processed Data (3 buckets)/Training/Under_Low (70).png
# ['115' '105' '106' ... '122' '114' '2']
# Processed Data (3 buckets)/Training/Under_Low (71).png
# ['114' '104' '107' ... '122' '113' '2']
# Processed Data (3 buckets)/Training/Under_Low (72).png
# ['115' '105' '107' ... '123' '112' '2']
# Processed Data (3 buckets)/Training/Under_Low (73).png
# ['109' '99' '101' ... '121' '111' '2']
# Processed Data (3 buckets)/Training/Under_Low (74).png
# ['107' '98' '101' ... '120' '110' '2']
# Processed Data (3 buckets)/Training/Under_Low (75).png
# ['107' '97' '99' ... '117' '104' '2']
# Processed Data (3 buckets)/Training/Under_Low (76).png
# ['136' '121' '122' ... '90' '96' '2']
# Processed Data (3 buckets)/Training/Under_Low (77).png
# ['136' '120' '122' ... '89' '96' '2']
# Processed Data (3 buckets)/Training/Under_Low (78).png
# ['137' '120' '121' ... '89' '96' '2']
# Processed Data (3 buckets)/Training/Under_Low (79).png
# ['139' '122' '121' ... '90' '96' '2']
# Processed Data (3 buckets)/Training/Under_Low (80).png
# ['138' '121' '120' ... '89' '94' '2']
# Processed Data (3 buckets)/Training/Under_Low (82).png
# ['138' '122' '121' ... '92' '98' '2']
# Processed Data (3 buckets)/Training/Under_Low (83).png
# ['138' '122' '121' ... '92' '95' '2']
# Processed Data (3 buckets)/Training/Under_Low (84).png
# ['142' '125' '123' ... '94' '98' '2']
# Processed Data (3 buckets)/Training/Under_Low (86).png
# ['146' '128' '124' ... '93' '99' '2']
# Processed Data (3 buckets)/Training/Under_Low (87).png
# ['145' '128' '124' ... '93' '99' '2']
# Processed Data (3 buckets)/Training/Under_Low (88).png
# ['109' '100' '103' ... '119' '111' '2']
# Processed Data (3 buckets)/Training/Under_Low (89).png
# ['110' '100' '104' ... '118' '109' '2']
# Processed Data (3 buckets)/Training/Under_Low (9).png
# ['172' '136' '137' ... '73' '122' '2']
# Processed Data (3 buckets)/Training/Under_Low (90).png
# ['110' '97' '95' ... '113' '101' '2']
# Processed Data (3 buckets)/Training/Under_Low (91).png
# ['111' '97' '96' ... '113' '101' '2']
# Processed Data (3 buckets)/Training/Under_Low (92).png
# ['110' '96' '94' ... '115' '103' '2']
# Processed Data (3 buckets)/Training/Under_Low (93).png
# ['111' '97' '96' ... '115' '103' '2']
# Processed Data (3 buckets)/Training/Under_Low (94).png
# ['111' '97' '96' ... '115' '101' '2']
# Processed Data (3 buckets)/Training/Under_Low (95).png
# ['106' '97' '99' ... '116' '106' '2']
# Processed Data (3 buckets)/Training/Under_Low (97).png
# ['107' '98' '99' ... '118' '108' '2']
# Processed Data (3 buckets)/Training/Under_Low (99).png
# ['107' '98' '95' ... '108' '99' '2']
