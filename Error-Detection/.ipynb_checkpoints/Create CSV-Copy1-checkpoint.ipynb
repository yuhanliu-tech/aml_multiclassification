# %% [markdown]
# option 1: convert to csv file- https://pub.towardsai.net/how-to-create-a-new-custom-dataset-from-images-9b95977964ab

# %% [markdown]
# LABELS
#
# **** 5 buckets:
#
# C: Close (0)
#
# F: Far (1)
#
# H: HighP (2)
#
# L: LowP (3)
#
# G: Good (4)
#
# ***** 3 buckets
#
# O: Overextruded (0)
# G: Good (1)
# U: Underextruded (2)

# %%
# Convert the images into a CSV
# Run the following code to convert all the images into a CSV and label them accordingly.

from PIL import Image
import numpy as np
import sys
import os
import csv

# %%
# default format can be changed as needed
def createFileList(myDir, format='.png'):
    fileList = []
    print(myDir)
    labels = []
    names = []
    keywords = {"O" : "0","G": "1", "U" : "2"} # keys and values updated to test data
    for root, dirs, files in os.walk(myDir, topdown=True):
        for name in files:
            if name.endswith(format):
                fullName = os.path.join(root, name)
                fileList.append(fullName)
            for keyword in keywords:
                if keyword in name:
                    labels.append(keywords[keyword])
            names.append(name)
    return fileList, labels, names

def createCSV(test_or_train):
    
    # load the original image
    myFileList, labels, names  = createFileList('Layer One Data (3 buckets)/Training/')
    csv_name = "training_layerone.csv"
    
    if (test_or_train == "test"):
        # load the original image
        myFileList, labels, names  = createFileList('Layer One Data (3 buckets)/Test/')
        csv_name = "test_layerone.csv"
        
    i = 0
    for file in myFileList:
        print(file)
        img_file = Image.open(file)
        # img_file.show()
    # get original image parameters...
        width, height = img_file.size
        format = img_file.format
        mode = img_file.mode
    # Make image Greyscale
        img_grey = img_file.convert('RGB') # L for greyscale, RGB for colored - can probably just use greyscale later? 
        #img_grey.save('result.png')
        #img_grey.show()
    # Save Greyscale values
        value = np.asarray(img_grey.getdata(), dtype=np.int).reshape((width, height, 3)) # must add third parameter 3 for RGB
        value = value.flatten()

        value = np.append(value,labels[i])
        i +=1

        print(value)
        with open(csv_name, 'a', newline='') as f: # save file as test_data.csv
            writer = csv.writer(f)
            writer.writerow(value)

# %%
createCSV("test")
createCSV("train")
# Out:
# Layer One Data (3 buckets)/Training/
# Layer One Data (3 buckets)/Test/
# Layer One Data (3 buckets)/Test/Good (1).png
# ['131' '118' '155' ... '68' '108' '1']
# Layer One Data (3 buckets)/Test/Good (1005).png
# ['145' '131' '170' ... '79' '119' '1']
# Layer One Data (3 buckets)/Test/Good (1006).png
# ['144' '131' '168' ... '79' '118' '1']
# Layer One Data (3 buckets)/Test/Good (101).png
# ['159' '112' '124' ... '69' '129' '1']
# Layer One Data (3 buckets)/Test/Good (1015).png
# ['144' '130' '165' ... '79' '118' '1']
# Layer One Data (3 buckets)/Test/Good (1016).png
# ['153' '136' '175' ... '84' '127' '1']
# Layer One Data (3 buckets)/Test/Good (1021).png
# ['145' '133' '170' ... '78' '118' '1']
# Layer One Data (3 buckets)/Test/Good (103).png
# ['132' '102' '127' ... '77' '129' '1']
# Layer One Data (3 buckets)/Test/Good (1033).png
# ['137' '124' '165' ... '68' '114' '1']
# Layer One Data (3 buckets)/Test/Good (1036).png
# ['147' '129' '159' ... '73' '109' '1']
# Layer One Data (3 buckets)/Test/Good (1049).png
# ['133' '120' '156' ... '76' '113' '1']
# Layer One Data (3 buckets)/Test/Good (1052).png
# ['131' '117' '152' ... '76' '113' '1']
# Layer One Data (3 buckets)/Test/Good (1062).png
# ['138' '125' '159' ... '73' '112' '1']
# Layer One Data (3 buckets)/Test/Good (1063).png
# ['135' '122' '157' ... '72' '107' '1']
# Layer One Data (3 buckets)/Test/Good (1068).png
# ['136' '123' '160' ... '76' '111' '1']
# Layer One Data (3 buckets)/Test/Good (1080).png
# ['136' '124' '161' ... '74' '112' '1']
# Layer One Data (3 buckets)/Test/Good (1089).png
# ['133' '120' '157' ... '75' '111' '1']
# Layer One Data (3 buckets)/Test/Good (1091).png
# ['135' '122' '159' ... '72' '109' '1']
# Layer One Data (3 buckets)/Test/Good (11).png
# ['152' '120' '127' ... '76' '118' '1']
# Layer One Data (3 buckets)/Test/Good (1100).png
# ['129' '117' '151' ... '71' '109' '1']
# Layer One Data (3 buckets)/Test/Good (1109).png
# C:\Users\littl\AppData\Local\Temp\ipykernel_14712\2106754344.py:44: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   value = np.asarray(img_grey.getdata(), dtype=np.int).reshape((width, height, 3)) # must add third parameter 3 for RGB
# ['130' '117' '165' ... '133' '136' '1']
# Layer One Data (3 buckets)/Test/Good (111).png
# ['124' '87' '113' ... '63' '123' '1']
# Layer One Data (3 buckets)/Test/Good (1110).png
# ['129' '115' '164' ... '124' '139' '1']
# Layer One Data (3 buckets)/Test/Good (1113).png
# ['122' '107' '154' ... '80' '122' '1']
# Layer One Data (3 buckets)/Test/Good (1116).png
# ['128' '109' '144' ... '67' '111' '1']
# Layer One Data (3 buckets)/Test/Good (1117).png
# ['129' '110' '146' ... '67' '111' '1']
# Layer One Data (3 buckets)/Test/Good (1119).png
# ['141' '124' '157' ... '81' '117' '1']
# Layer One Data (3 buckets)/Test/Good (1124).png
# ['138' '118' '170' ... '123' '140' '1']
# Layer One Data (3 buckets)/Test/Good (1127).png
# ['130' '114' '158' ... '95' '122' '1']
# Layer One Data (3 buckets)/Test/Good (1128).png
# ['127' '116' '158' ... '123' '127' '1']
# Layer One Data (3 buckets)/Test/Good (1133).png
# ['129' '112' '153' ... '69' '117' '1']
# Layer One Data (3 buckets)/Test/Good (1134).png
# ['126' '108' '150' ... '67' '117' '1']
# Layer One Data (3 buckets)/Test/Good (1135).png
# ['124' '104' '146' ... '70' '117' '1']
# Layer One Data (3 buckets)/Test/Good (1137).png
# ['141' '115' '149' ... '71' '118' '1']
# Layer One Data (3 buckets)/Test/Good (115).png
# ['121' '79' '104' ... '60' '115' '1']
# Layer One Data (3 buckets)/Test/Good (116).png
# ['122' '82' '108' ... '61' '117' '1']
# Layer One Data (3 buckets)/Test/Good (1161).png
# ['141' '120' '156' ... '80' '127' '1']
# Layer One Data (3 buckets)/Test/Good (1165).png
# ['142' '124' '167' ... '81' '126' '1']
# Layer One Data (3 buckets)/Test/Good (1174).png
# ['128' '112' '148' ... '76' '113' '1']
# Layer One Data (3 buckets)/Test/Good (1175).png
# ['131' '116' '152' ... '77' '115' '1']
# Layer One Data (3 buckets)/Test/Good (1181).png
# ['130' '113' '144' ... '74' '112' '1']
# Layer One Data (3 buckets)/Test/Good (1197).png
# ['129' '114' '150' ... '71' '112' '1']
# Layer One Data (3 buckets)/Test/Good (1198).png
# ['129' '113' '148' ... '69' '109' '1']
# Layer One Data (3 buckets)/Test/Good (1209).png
# ['129' '113' '149' ... '72' '113' '1']
# Layer One Data (3 buckets)/Test/Good (1210).png
# ['128' '112' '146' ... '70' '110' '1']
# Layer One Data (3 buckets)/Test/Good (1211).png
# ['127' '112' '148' ... '71' '111' '1']
# Layer One Data (3 buckets)/Test/Good (1212).png
# ['126' '111' '147' ... '71' '110' '1']
# Layer One Data (3 buckets)/Test/Good (1221).png
# ['133' '116' '148' ... '71' '110' '1']
# Layer One Data (3 buckets)/Test/Good (123).png
# ['162' '114' '116' ... '67' '117' '1']
# Layer One Data (3 buckets)/Test/Good (1231).png
# ['133' '116' '152' ... '73' '114' '1']
# Layer One Data (3 buckets)/Test/Good (1232).png
# ['132' '116' '154' ... '74' '116' '1']
# Layer One Data (3 buckets)/Test/Good (1234).png
# ['128' '114' '149' ... '73' '113' '1']
# Layer One Data (3 buckets)/Test/Good (1238).png
# ['129' '113' '148' ... '72' '113' '1']
# Layer One Data (3 buckets)/Test/Good (1239).png
# ['129' '113' '148' ... '70' '112' '1']
# Layer One Data (3 buckets)/Test/Good (1241).png
# ['132' '116' '151' ... '69' '110' '1']
# Layer One Data (3 buckets)/Test/Good (1249).png
# ['150' '139' '177' ... '84' '120' '1']
# Layer One Data (3 buckets)/Test/Good (1250).png
# ['140' '130' '172' ... '70' '115' '1']
# Layer One Data (3 buckets)/Test/Good (1251).png
# ['153' '141' '179' ... '78' '120' '1']
# Layer One Data (3 buckets)/Test/Good (1257).png
# ['146' '132' '166' ... '78' '117' '1']
# Layer One Data (3 buckets)/Test/Good (1260).png
# ['153' '140' '177' ... '77' '119' '1']
# Layer One Data (3 buckets)/Test/Good (1270).png
# ['147' '136' '174' ... '82' '121' '1']
# Layer One Data (3 buckets)/Test/Good (1288).png
# ['134' '123' '158' ... '73' '110' '1']
# Layer One Data (3 buckets)/Test/Good (129).png
# ['169' '128' '135' ... '70' '128' '1']
# Layer One Data (3 buckets)/Test/Good (1291).png
# ['133' '123' '157' ... '75' '109' '1']
# Layer One Data (3 buckets)/Test/Good (1292).png
# ['135' '125' '160' ... '73' '108' '1']
# Layer One Data (3 buckets)/Test/Good (1298).png
# ['133' '123' '156' ... '67' '102' '1']
# Layer One Data (3 buckets)/Test/Good (130).png
# ['170' '129' '129' ... '66' '120' '1']
# Layer One Data (3 buckets)/Test/Good (131).png
# ['170' '133' '139' ... '67' '125' '1']
# Layer One Data (3 buckets)/Test/Good (136).png
# ['151' '120' '103' ... '55' '86' '1']
# Layer One Data (3 buckets)/Test/Good (140).png
# ['112' '103' '117' ... '114' '118' '1']
# Layer One Data (3 buckets)/Test/Good (142).png
# ['125' '112' '115' ... '117' '111' '1']
# Layer One Data (3 buckets)/Test/Good (15).png
# ['173' '139' '135' ... '54' '111' '1']
# Layer One Data (3 buckets)/Test/Good (151).png
# ['135' '123' '118' ... '104' '96' '1']
# Layer One Data (3 buckets)/Test/Good (155).png
# ['131' '120' '116' ... '97' '96' '1']
# Layer One Data (3 buckets)/Test/Good (164).png
# ['147' '114' '126' ... '91' '125' '1']
# Layer One Data (3 buckets)/Test/Good (168).png
# ['143' '112' '124' ... '97' '124' '1']
# Layer One Data (3 buckets)/Test/Good (17).png
# ['167' '140' '114' ... '72' '87' '1']
# Layer One Data (3 buckets)/Test/Good (170).png
# ['123' '94' '117' ... '87' '120' '1']
# Layer One Data (3 buckets)/Test/Good (177).png
# ['122' '94' '118' ... '100' '128' '1']
# Layer One Data (3 buckets)/Test/Good (192).png
# ['122' '93' '120' ... '106' '128' '1']
# Layer One Data (3 buckets)/Test/Good (193).png
# ['125' '95' '122' ... '108' '133' '1']
# Layer One Data (3 buckets)/Test/Good (196).png
# ['118' '94' '124' ... '107' '132' '1']
# Layer One Data (3 buckets)/Test/Good (208).png
# ['130' '105' '126' ... '100' '131' '1']
# Layer One Data (3 buckets)/Test/Good (212).png
# ['99' '73' '116' ... '81' '130' '1']
# Layer One Data (3 buckets)/Test/Good (217).png
# ['152' '89' '71' ... '72' '78' '1']
# Layer One Data (3 buckets)/Test/Good (219).png
# ['161' '96' '72' ... '82' '77' '1']
# Layer One Data (3 buckets)/Test/Good (225).png
# ['150' '101' '107' ... '83' '110' '1']
# Layer One Data (3 buckets)/Test/Good (235).png
# ['140' '105' '128' ... '90' '131' '1']
# Layer One Data (3 buckets)/Test/Good (237).png
# ['138' '104' '128' ... '90' '131' '1']
# Layer One Data (3 buckets)/Test/Good (24).png
# ['171' '137' '131' ... '65' '112' '1']
# Layer One Data (3 buckets)/Test/Good (242).png
# ['144' '108' '133' ... '89' '135' '1']
# Layer One Data (3 buckets)/Test/Good (246).png
# ['144' '108' '134' ... '89' '135' '1']
# Layer One Data (3 buckets)/Test/Good (247).png
# ['145' '109' '134' ... '88' '137' '1']
# Layer One Data (3 buckets)/Test/Good (249).png
# ['144' '108' '136' ... '90' '138' '1']
# Layer One Data (3 buckets)/Test/Good (268).png
# ['124' '92' '131' ... '96' '138' '1']
# Layer One Data (3 buckets)/Test/Good (27).png
# ['128' '106' '101' ... '78' '98' '1']
# Layer One Data (3 buckets)/Test/Good (275).png
# ['128' '95' '131' ... '106' '141' '1']
# Layer One Data (3 buckets)/Test/Good (281).png
# ['115' '90' '122' ... '103' '135' '1']
# Layer One Data (3 buckets)/Test/Good (291).png
# ['117' '91' '130' ... '108' '144' '1']
# Layer One Data (3 buckets)/Test/Good (302).png
# ['121' '105' '98' ... '128' '112' '1']
# Layer One Data (3 buckets)/Test/Good (306).png
# ['118' '104' '94' ... '135' '114' '1']
# Layer One Data (3 buckets)/Test/Good (331).png
# ['80' '70' '85' ... '115' '111' '1']
# Layer One Data (3 buckets)/Test/Good (335).png
# ['110' '99' '100' ... '128' '122' '1']
# Layer One Data (3 buckets)/Test/Good (340).png
# ['132' '118' '109' ... '115' '112' '1']
# Layer One Data (3 buckets)/Test/Good (350).png
# ['145' '129' '112' ... '125' '112' '1']
# Layer One Data (3 buckets)/Test/Good (356).png
# ['135' '118' '105' ... '113' '105' '1']
# Layer One Data (3 buckets)/Test/Good (363).png
# ['132' '114' '102' ... '104' '101' '1']
# Layer One Data (3 buckets)/Test/Good (370).png
# ['130' '114' '105' ... '117' '109' '1']
# Layer One Data (3 buckets)/Test/Good (377).png
# ['124' '109' '102' ... '120' '110' '1']
# Layer One Data (3 buckets)/Test/Good (379).png
# ['124' '108' '101' ... '121' '110' '1']
# Layer One Data (3 buckets)/Test/Good (386).png
# ['123' '107' '97' ... '121' '110' '1']
# Layer One Data (3 buckets)/Test/Good (387).png
# ['122' '106' '97' ... '123' '109' '1']
# Layer One Data (3 buckets)/Test/Good (394).png
# ['115' '100' '95' ... '125' '115' '1']
# Layer One Data (3 buckets)/Test/Good (397).png
# ['111' '96' '91' ... '123' '111' '1']
# Layer One Data (3 buckets)/Test/Good (398).png
# ['111' '97' '91' ... '125' '112' '1']
# Layer One Data (3 buckets)/Test/Good (399).png
# ['139' '123' '106' ... '146' '119' '1']
# Layer One Data (3 buckets)/Test/Good (401).png
# ['133' '119' '106' ... '147' '119' '1']
# Layer One Data (3 buckets)/Test/Good (408).png
# ['110' '100' '96' ... '129' '117' '1']
# Layer One Data (3 buckets)/Test/Good (41).png
# ['140' '95' '111' ... '72' '121' '1']
# Layer One Data (3 buckets)/Test/Good (413).png
# ['131' '117' '105' ... '129' '113' '1']
# Layer One Data (3 buckets)/Test/Good (423).png
# ['155' '140' '136' ... '160' '149' '1']
# Layer One Data (3 buckets)/Test/Good (432).png
# ['126' '111' '106' ... '115' '108' '1']
# Layer One Data (3 buckets)/Test/Good (434).png
# ['129' '113' '108' ... '116' '107' '1']
# Layer One Data (3 buckets)/Test/Good (435).png
# ['128' '113' '107' ... '113' '107' '1']
# Layer One Data (3 buckets)/Test/Good (437).png
# ['131' '115' '107' ... '112' '105' '1']
# Layer One Data (3 buckets)/Test/Good (439).png
# ['132' '116' '108' ... '109' '103' '1']
# Layer One Data (3 buckets)/Test/Good (442).png
# ['136' '119' '109' ... '109' '102' '1']
# Layer One Data (3 buckets)/Test/Good (443).png
# ['136' '119' '109' ... '109' '103' '1']
# Layer One Data (3 buckets)/Test/Good (445).png
# ['138' '121' '110' ... '112' '103' '1']
# Layer One Data (3 buckets)/Test/Good (447).png
# ['138' '120' '110' ... '109' '103' '1']
# Layer One Data (3 buckets)/Test/Good (448).png
# ['138' '121' '110' ... '109' '103' '1']
# Layer One Data (3 buckets)/Test/Good (449).png
# ['137' '120' '108' ... '111' '103' '1']
# Layer One Data (3 buckets)/Test/Good (459).png
# ['121' '105' '98' ... '104' '97' '1']
# Layer One Data (3 buckets)/Test/Good (465).png
# ['121' '105' '99' ... '108' '100' '1']
# Layer One Data (3 buckets)/Test/Good (468).png
# ['122' '106' '100' ... '114' '104' '1']
# Layer One Data (3 buckets)/Test/Good (477).png
# ['126' '108' '104' ... '124' '115' '1']
# Layer One Data (3 buckets)/Test/Good (480).png
# ['116' '102' '93' ... '115' '104' '1']
# Layer One Data (3 buckets)/Test/Good (481).png
# ['115' '101' '94' ... '113' '103' '1']
# Layer One Data (3 buckets)/Test/Good (486).png
# ['115' '101' '97' ... '128' '115' '1']
# Layer One Data (3 buckets)/Test/Good (489).png
# ['122' '107' '100' ... '144' '124' '1']
# Layer One Data (3 buckets)/Test/Good (492).png
# ['126' '111' '101' ... '152' '126' '1']
# Layer One Data (3 buckets)/Test/Good (494).png
# ['127' '110' '101' ... '154' '128' '1']
# Layer One Data (3 buckets)/Test/Good (496).png
# ['127' '111' '104' ... '150' '132' '1']
# Layer One Data (3 buckets)/Test/Good (497).png
# ['127' '111' '105' ... '152' '133' '1']
# Layer One Data (3 buckets)/Test/Good (50).png
# ['240' '192' '165' ... '90' '133' '1']
# Layer One Data (3 buckets)/Test/Good (511).png
# ['146' '130' '126' ... '158' '143' '1']
# Layer One Data (3 buckets)/Test/Good (521).png
# ['127' '111' '104' ... '113' '106' '1']
# Layer One Data (3 buckets)/Test/Good (524).png
# ['129' '113' '105' ... '111' '107' '1']
# Layer One Data (3 buckets)/Test/Good (527).png
# ['130' '115' '107' ... '119' '110' '1']
# Layer One Data (3 buckets)/Test/Good (536).png
# ['127' '111' '104' ... '121' '112' '1']
# Layer One Data (3 buckets)/Test/Good (54).png
# ['197' '157' '149' ... '80' '131' '1']
# Layer One Data (3 buckets)/Test/Good (549).png
# ['109' '95' '92' ... '124' '109' '1']
# Layer One Data (3 buckets)/Test/Good (561).png
# ['106' '89' '88' ... '52' '76' '1']
# Layer One Data (3 buckets)/Test/Good (562).png
# ['137' '111' '99' ... '57' '81' '1']
# Layer One Data (3 buckets)/Test/Good (566).png
# ['113' '100' '94' ... '130' '110' '1']
# Layer One Data (3 buckets)/Test/Good (569).png
# ['110' '97' '92' ... '130' '112' '1']
# Layer One Data (3 buckets)/Test/Good (57).png
# ['136' '103' '119' ... '77' '124' '1']
# Layer One Data (3 buckets)/Test/Good (572).png
# ['106' '93' '87' ... '127' '107' '1']
# Layer One Data (3 buckets)/Test/Good (576).png
# ['136' '124' '161' ... '67' '108' '1']
# Layer One Data (3 buckets)/Test/Good (577).png
# ['142' '129' '178' ... '117' '139' '1']
# Layer One Data (3 buckets)/Test/Good (58).png
# ['130' '98' '116' ... '77' '123' '1']
# Layer One Data (3 buckets)/Test/Good (581).png
# ['135' '126' '171' ... '136' '134' '1']
# Layer One Data (3 buckets)/Test/Good (605).png
# ['146' '128' '164' ... '95' '126' '1']
# Layer One Data (3 buckets)/Test/Good (608).png
# ['145' '128' '162' ... '139' '133' '1']
# Layer One Data (3 buckets)/Test/Good (610).png
# ['129' '114' '159' ... '104' '125' '1']
# Layer One Data (3 buckets)/Test/Good (611).png
# ['130' '114' '156' ... '113' '127' '1']
# Layer One Data (3 buckets)/Test/Good (63).png
# ['181' '145' '139' ... '74' '122' '1']
# Layer One Data (3 buckets)/Test/Good (649).png
# ['126' '112' '153' ... '78' '115' '1']
# Layer One Data (3 buckets)/Test/Good (651).png
# ['122' '107' '148' ... '78' '116' '1']
# Layer One Data (3 buckets)/Test/Good (652).png
# ['121' '105' '145' ... '78' '116' '1']
# Layer One Data (3 buckets)/Test/Good (668).png
# ['132' '116' '158' ... '75' '115' '1']
# Layer One Data (3 buckets)/Test/Good (669).png
# ['125' '110' '150' ... '73' '115' '1']
# Layer One Data (3 buckets)/Test/Good (671).png
# ['122' '108' '148' ... '72' '115' '1']
# Layer One Data (3 buckets)/Test/Good (678).png
# ['134' '125' '177' ... '163' '146' '1']
# Layer One Data (3 buckets)/Test/Good (685).png
# ['127' '117' '159' ... '124' '129' '1']
# Layer One Data (3 buckets)/Test/Good (689).png
# ['129' '119' '161' ... '166' '136' '1']
# Layer One Data (3 buckets)/Test/Good (696).png
# ['122' '111' '148' ... '151' '131' '1']
# Layer One Data (3 buckets)/Test/Good (700).png
# ['127' '117' '158' ... '107' '119' '1']
# Layer One Data (3 buckets)/Test/Good (702).png
# ['119' '77' '101' ... '62' '111' '1']
# Layer One Data (3 buckets)/Test/Good (717).png
# ['126' '111' '150' ... '100' '120' '1']
# Layer One Data (3 buckets)/Test/Good (73).png
# ['142' '101' '115' ... '66' '122' '1']
# Layer One Data (3 buckets)/Test/Good (730).png
# ['123' '108' '141' ... '84' '113' '1']
# Layer One Data (3 buckets)/Test/Good (736).png
# ['126' '112' '154' ... '83' '116' '1']
# Layer One Data (3 buckets)/Test/Good (745).png
# ['129' '116' '158' ... '80' '116' '1']
# Layer One Data (3 buckets)/Test/Good (749).png
# ['128' '112' '149' ... '78' '111' '1']
# Layer One Data (3 buckets)/Test/Good (757).png
# ['127' '114' '155' ... '74' '113' '1']
# Layer One Data (3 buckets)/Test/Good (758).png
# ['125' '112' '152' ... '73' '112' '1']
# Layer One Data (3 buckets)/Test/Good (76).png
# ['137' '100' '128' ... '68' '133' '1']
# Layer One Data (3 buckets)/Test/Good (765).png
# ['156' '135' '171' ... '83' '124' '1']
# Layer One Data (3 buckets)/Test/Good (769).png
# ['153' '135' '179' ... '83' '130' '1']
# Layer One Data (3 buckets)/Test/Good (77).png
# ['132' '96' '124' ... '66' '132' '1']
# Layer One Data (3 buckets)/Test/Good (772).png
# ['153' '134' '177' ... '84' '131' '1']
# Layer One Data (3 buckets)/Test/Good (779).png
# ['140' '127' '165' ... '79' '118' '1']
# Layer One Data (3 buckets)/Test/Good (780).png
# ['136' '123' '160' ... '78' '116' '1']
# Layer One Data (3 buckets)/Test/Good (784).png
# ['137' '122' '159' ... '75' '115' '1']
# Layer One Data (3 buckets)/Test/Good (785).png
# ['138' '125' '163' ... '75' '117' '1']
# Layer One Data (3 buckets)/Test/Good (787).png
# ['139' '124' '164' ... '74' '115' '1']
# Layer One Data (3 buckets)/Test/Good (79).png
# ['141' '103' '128' ... '70' '133' '1']
# Layer One Data (3 buckets)/Test/Good (790).png
# ['144' '126' '156' ... '75' '112' '1']
# Layer One Data (3 buckets)/Test/Good (791).png
# ['144' '125' '156' ... '75' '111' '1']
# Layer One Data (3 buckets)/Test/Good (814).png
# ['134' '121' '159' ... '72' '111' '1']
# Layer One Data (3 buckets)/Test/Good (816).png
# ['133' '119' '152' ... '73' '111' '1']
# Layer One Data (3 buckets)/Test/Good (824).png
# ['136' '123' '161' ... '76' '112' '1']
# Layer One Data (3 buckets)/Test/Good (831).png
# ['132' '120' '156' ... '74' '113' '1']
# Layer One Data (3 buckets)/Test/Good (834).png
# ['134' '121' '157' ... '73' '110' '1']
# Layer One Data (3 buckets)/Test/Good (836).png
# ['131' '119' '151' ... '71' '109' '1']
# Layer One Data (3 buckets)/Test/Good (842).png
# ['131' '117' '152' ... '70' '108' '1']
# Layer One Data (3 buckets)/Test/Good (846).png
# ['132' '121' '156' ... '73' '112' '1']
# Layer One Data (3 buckets)/Test/Good (851).png
# ['124' '110' '145' ... '75' '111' '1']
# Layer One Data (3 buckets)/Test/Good (864).png
# ['131' '118' '151' ... '70' '108' '1']
# Layer One Data (3 buckets)/Test/Good (866).png
# ['130' '117' '150' ... '71' '109' '1']
# Layer One Data (3 buckets)/Test/Good (868).png
# ['130' '118' '152' ... '72' '111' '1']
# Layer One Data (3 buckets)/Test/Good (869).png
# ['132' '121' '157' ... '72' '109' '1']
# Layer One Data (3 buckets)/Test/Good (87).png
# ['155' '115' '126' ... '68' '129' '1']
# Layer One Data (3 buckets)/Test/Good (870).png
# ['131' '118' '154' ... '73' '110' '1']
# Layer One Data (3 buckets)/Test/Good (883).png
# ['138' '126' '162' ... '72' '115' '1']
# Layer One Data (3 buckets)/Test/Good (891).png
# ['143' '130' '168' ... '78' '118' '1']
# Layer One Data (3 buckets)/Test/Good (9).png
# ['158' '126' '130' ... '74' '116' '1']
# Layer One Data (3 buckets)/Test/Good (901).png
# ['136' '123' '159' ... '76' '116' '1']
# Layer One Data (3 buckets)/Test/Good (907).png
# ['136' '123' '159' ... '74' '113' '1']
# Layer One Data (3 buckets)/Test/Good (910).png
# ['137' '124' '160' ... '73' '114' '1']
# Layer One Data (3 buckets)/Test/Good (912).png
# ['136' '121' '157' ... '74' '112' '1']
# Layer One Data (3 buckets)/Test/Good (921).png
# ['138' '124' '162' ... '75' '114' '1']
# Layer One Data (3 buckets)/Test/Good (927).png
# ['128' '116' '151' ... '73' '109' '1']
# Layer One Data (3 buckets)/Test/Good (929).png
# ['133' '121' '156' ... '72' '110' '1']
# Layer One Data (3 buckets)/Test/Good (93).png
# ['193' '148' '138' ... '65' '122' '1']
# Layer One Data (3 buckets)/Test/Good (930).png
# ['133' '120' '158' ... '72' '110' '1']
# Layer One Data (3 buckets)/Test/Good (931).png
# ['135' '121' '158' ... '73' '111' '1']
# Layer One Data (3 buckets)/Test/Good (936).png
# ['136' '121' '156' ... '71' '110' '1']
# Layer One Data (3 buckets)/Test/Good (94).png
# ['194' '148' '141' ... '66' '123' '1']
# Layer One Data (3 buckets)/Test/Good (946).png
# ['132' '120' '156' ... '72' '111' '1']
# Layer One Data (3 buckets)/Test/Good (955).png
# ['131' '119' '154' ... '71' '109' '1']
# Layer One Data (3 buckets)/Test/Good (967).png
# ['132' '119' '152' ... '71' '108' '1']
# Layer One Data (3 buckets)/Test/Good (974).png
# ['127' '115' '150' ... '71' '105' '1']
# Layer One Data (3 buckets)/Test/Good (986).png
# ['128' '115' '148' ... '68' '107' '1']
# Layer One Data (3 buckets)/Test/Good (991).png
# ['130' '117' '152' ... '69' '108' '1']
# Layer One Data (3 buckets)/Test/Good (998).png
# ['127' '115' '149' ... '70' '107' '1']
# Layer One Data (3 buckets)/Test/Over_Far (1).png
# ['128' '121' '180' ... '71' '130' '0']
# Layer One Data (3 buckets)/Test/Over_Far (106).png
# ['71' '46' '85' ... '78' '115' '0']
# Layer One Data (3 buckets)/Test/Over_Far (107).png
# ['69' '44' '84' ... '77' '116' '0']
# Layer One Data (3 buckets)/Test/Over_Far (110).png
# ['73' '50' '94' ... '83' '125' '0']
# Layer One Data (3 buckets)/Test/Over_Far (116).png
# ['77' '55' '96' ... '81' '121' '0']
# Layer One Data (3 buckets)/Test/Over_Far (117).png
# ['80' '59' '99' ... '82' '122' '0']
# Layer One Data (3 buckets)/Test/Over_Far (122).png
# ['106' '86' '123' ... '80' '120' '0']
# Layer One Data (3 buckets)/Test/Over_Far (130).png
# ['110' '94' '133' ... '75' '119' '0']
# Layer One Data (3 buckets)/Test/Over_Far (134).png
# ['111' '96' '126' ... '73' '112' '0']
# Layer One Data (3 buckets)/Test/Over_Far (137).png
# ['113' '97' '128' ... '72' '106' '0']
# Layer One Data (3 buckets)/Test/Over_Far (15).png
# ['150' '133' '175' ... '83' '130' '0']
# Layer One Data (3 buckets)/Test/Over_Far (153).png
# ['100' '84' '119' ... '76' '115' '0']
# Layer One Data (3 buckets)/Test/Over_Far (163).png
# ['66' '46' '83' ... '80' '113' '0']
# Layer One Data (3 buckets)/Test/Over_Far (164).png
# ['66' '46' '83' ... '80' '114' '0']
# Layer One Data (3 buckets)/Test/Over_Far (169).png
# ['60' '39' '80' ... '77' '112' '0']
# Layer One Data (3 buckets)/Test/Over_Far (181).png
# ['92' '77' '117' ... '80' '118' '0']
# Layer One Data (3 buckets)/Test/Over_Far (19).png
# ['132' '111' '155' ... '89' '133' '0']
# Layer One Data (3 buckets)/Test/Over_Far (192).png
# ['109' '96' '138' ... '79' '118' '0']
# Layer One Data (3 buckets)/Test/Over_Far (20).png
# ['132' '112' '153' ... '85' '129' '0']
# Layer One Data (3 buckets)/Test/Over_Far (201).png
# ['118' '105' '150' ... '74' '119' '0']
# Layer One Data (3 buckets)/Test/Over_Far (21).png
# ['139' '117' '165' ... '84' '134' '0']
# Layer One Data (3 buckets)/Test/Over_Far (210).png
# ['104' '91' '137' ... '86' '130' '0']
# Layer One Data (3 buckets)/Test/Over_Far (211).png
# ['103' '90' '132' ... '86' '130' '0']
# Layer One Data (3 buckets)/Test/Over_Far (214).png
# ['98' '85' '127' ... '85' '124' '0']
# Layer One Data (3 buckets)/Test/Over_Far (217).png
# ['90' '74' '118' ... '83' '123' '0']
# Layer One Data (3 buckets)/Test/Over_Far (218).png
# ['84' '69' '113' ... '83' '122' '0']
# Layer One Data (3 buckets)/Test/Over_Far (22).png
# ['126' '109' '142' ... '77' '116' '0']
# Layer One Data (3 buckets)/Test/Over_Far (225).png
# ['64' '46' '86' ... '86' '118' '0']
# Layer One Data (3 buckets)/Test/Over_Far (228).png
# ['64' '45' '87' ... '87' '122' '0']
# Layer One Data (3 buckets)/Test/Over_Far (229).png
# ['63' '44' '87' ... '89' '124' '0']
# Layer One Data (3 buckets)/Test/Over_Far (234).png
# ['66' '47' '89' ... '92' '125' '0']
# Layer One Data (3 buckets)/Test/Over_Far (235).png
# ['66' '47' '89' ... '92' '126' '0']
# Layer One Data (3 buckets)/Test/Over_Far (236).png
# ['65' '47' '87' ... '91' '123' '0']
# Layer One Data (3 buckets)/Test/Over_Far (238).png
# ['67' '49' '89' ... '91' '124' '0']
# Layer One Data (3 buckets)/Test/Over_Far (250).png
# ['102' '89' '130' ... '75' '116' '0']
# Layer One Data (3 buckets)/Test/Over_Far (260).png
# ['101' '90' '129' ... '82' '121' '0']
# Layer One Data (3 buckets)/Test/Over_Far (262).png
# ['99' '86' '126' ... '79' '119' '0']
# Layer One Data (3 buckets)/Test/Over_Far (266).png
# ['93' '82' '121' ... '85' '124' '0']
# Layer One Data (3 buckets)/Test/Over_Far (275).png
# ['75' '63' '97' ... '88' '121' '0']
# Layer One Data (3 buckets)/Test/Over_Far (276).png
# ['73' '58' '94' ... '89' '122' '0']
# Layer One Data (3 buckets)/Test/Over_Far (282).png
# ['60' '41' '78' ... '92' '124' '0']
# Layer One Data (3 buckets)/Test/Over_Far (298).png
# ['80' '65' '107' ... '97' '132' '0']
# Layer One Data (3 buckets)/Test/Over_Far (299).png
# ['83' '70' '109' ... '93' '128' '0']
# Layer One Data (3 buckets)/Test/Over_Far (31).png
# ['111' '94' '129' ... '80' '115' '0']
# Layer One Data (3 buckets)/Test/Over_Far (311).png
# ['78' '54' '96' ... '84' '127' '0']
# Layer One Data (3 buckets)/Test/Over_Far (312).png
# ['76' '53' '97' ... '84' '127' '0']
# Layer One Data (3 buckets)/Test/Over_Far (313).png
# ['76' '53' '96' ... '83' '128' '0']
# Layer One Data (3 buckets)/Test/Over_Far (322).png
# ['73' '51' '94' ... '87' '129' '0']
# Layer One Data (3 buckets)/Test/Over_Far (330).png
# ['101' '84' '122' ... '72' '111' '0']
# Layer One Data (3 buckets)/Test/Over_Far (332).png
# ['110' '95' '130' ... '72' '112' '0']
# Layer One Data (3 buckets)/Test/Over_Far (333).png
# ['113' '96' '131' ... '75' '113' '0']
# Layer One Data (3 buckets)/Test/Over_Far (335).png
# ['111' '93' '129' ... '72' '112' '0']
# Layer One Data (3 buckets)/Test/Over_Far (339).png
# ['89' '69' '108' ... '94' '132' '0']
# Layer One Data (3 buckets)/Test/Over_Far (34).png
# ['103' '84' '121' ... '79' '114' '0']
# Layer One Data (3 buckets)/Test/Over_Far (342).png
# ['73' '53' '92' ... '104' '125' '0']
# Layer One Data (3 buckets)/Test/Over_Far (35).png
# ['96' '77' '115' ... '79' '117' '0']
# Layer One Data (3 buckets)/Test/Over_Far (351).png
# ['66' '44' '87' ... '85' '110' '0']
# Layer One Data (3 buckets)/Test/Over_Far (352).png
# ['73' '51' '101' ... '95' '131' '0']
# Layer One Data (3 buckets)/Test/Over_Far (358).png
# ['76' '54' '95' ... '102' '134' '0']
# Layer One Data (3 buckets)/Test/Over_Far (361).png
# ['92' '74' '111' ... '106' '140' '0']
# Layer One Data (3 buckets)/Test/Over_Far (371).png
# ['91' '73' '111' ... '113' '149' '0']
# Layer One Data (3 buckets)/Test/Over_Far (389).png
# ['78' '55' '100' ... '122' '166' '0']
# Layer One Data (3 buckets)/Test/Over_Far (390).png
# ['80' '59' '104' ... '118' '162' '0']
# Layer One Data (3 buckets)/Test/Over_Far (392).png
# ['84' '66' '103' ... '116' '151' '0']
# Layer One Data (3 buckets)/Test/Over_Far (393).png
# ['93' '76' '112' ... '100' '137' '0']
# Layer One Data (3 buckets)/Test/Over_Far (399).png
# ['103' '87' '121' ... '70' '107' '0']
# Layer One Data (3 buckets)/Test/Over_Far (400).png
# ['100' '83' '119' ... '70' '108' '0']
# Layer One Data (3 buckets)/Test/Over_Far (402).png
# ['85' '67' '102' ... '120' '157' '0']
# Layer One Data (3 buckets)/Test/Over_Far (407).png
# ['67' '47' '88' ... '114' '151' '0']
# Layer One Data (3 buckets)/Test/Over_Far (411).png
# ['60' '39' '82' ... '107' '126' '0']
# Layer One Data (3 buckets)/Test/Over_Far (413).png
# ['62' '41' '83' ... '104' '125' '0']
# Layer One Data (3 buckets)/Test/Over_Far (420).png
# ['72' '54' '99' ... '126' '145' '0']
# Layer One Data (3 buckets)/Test/Over_Far (422).png
# ['82' '67' '110' ... '137' '182' '0']
# Layer One Data (3 buckets)/Test/Over_Far (426).png
# ['103' '86' '119' ... '67' '102' '0']
# Layer One Data (3 buckets)/Test/Over_Far (435).png
# ['65' '46' '84' ... '129' '153' '0']
# Layer One Data (3 buckets)/Test/Over_Far (439).png
# ['61' '41' '83' ... '124' '148' '0']
# Layer One Data (3 buckets)/Test/Over_Far (440).png
# ['58' '38' '80' ... '122' '158' '0']
# Layer One Data (3 buckets)/Test/Over_Far (441).png
# ['60' '40' '78' ... '115' '140' '0']
# Layer One Data (3 buckets)/Test/Over_Far (448).png
# ['70' '52' '89' ... '120' '158' '0']
# Layer One Data (3 buckets)/Test/Over_Far (463).png
# ['66' '48' '86' ... '120' '148' '0']
# Layer One Data (3 buckets)/Test/Over_Far (464).png
# ['63' '46' '84' ... '125' '148' '0']
# Layer One Data (3 buckets)/Test/Over_Far (467).png
# ['60' '42' '84' ... '120' '142' '0']
# Layer One Data (3 buckets)/Test/Over_Far (48).png
# ['78' '51' '93' ... '80' '121' '0']
# Layer One Data (3 buckets)/Test/Over_Far (484).png
# ['97' '82' '118' ... '64' '102' '0']
# Layer One Data (3 buckets)/Test/Over_Far (489).png
# ['75' '59' '102' ... '115' '149' '0']
# Layer One Data (3 buckets)/Test/Over_Far (490).png
# ['69' '53' '95' ... '106' '141' '0']
# Layer One Data (3 buckets)/Test/Over_Far (497).png
# ['57' '39' '80' ... '109' '132' '0']
# Layer One Data (3 buckets)/Test/Over_Far (506).png
# ['66' '49' '89' ... '117' '141' '0']
# Layer One Data (3 buckets)/Test/Over_Far (508).png
# ['71' '55' '97' ... '115' '148' '0']
# Layer One Data (3 buckets)/Test/Over_Far (510).png
# ['82' '68' '110' ... '83' '123' '0']
# Layer One Data (3 buckets)/Test/Over_Far (513).png
# ['93' '80' '117' ... '64' '101' '0']
# Layer One Data (3 buckets)/Test/Over_Far (517).png
# ['80' '67' '105' ... '120' '146' '0']
# Layer One Data (3 buckets)/Test/Over_Far (518).png
# ['78' '64' '101' ... '118' '150' '0']
# Layer One Data (3 buckets)/Test/Over_Far (52).png
# ['78' '54' '98' ... '81' '122' '0']
# Layer One Data (3 buckets)/Test/Over_Far (539).png
# ['79' '63' '100' ... '122' '168' '0']
# Layer One Data (3 buckets)/Test/Over_Far (540).png
# ['78' '65' '99' ... '77' '111' '0']
# Layer One Data (3 buckets)/Test/Over_Far (546).png
# ['140' '132' '196' ... '77' '144' '0']
# Layer One Data (3 buckets)/Test/Over_Far (552).png
# ['120' '108' '107' ... '124' '113' '0']
# Layer One Data (3 buckets)/Test/Over_Far (562).png
# ['111' '101' '103' ... '131' '119' '0']
# Layer One Data (3 buckets)/Test/Over_Far (574).png
# ['105' '97' '101' ... '126' '116' '0']
# Layer One Data (3 buckets)/Test/Over_Far (578).png
# ['168' '141' '117' ... '69' '86' '0']
# Layer One Data (3 buckets)/Test/Over_Far (602).png
# ['144' '131' '124' ... '134' '124' '0']
# Layer One Data (3 buckets)/Test/Over_Far (606).png
# ['145' '136' '130' ... '121' '117' '0']
# Layer One Data (3 buckets)/Test/Over_Far (611).png
# ['149' '139' '135' ... '120' '118' '0']
# Layer One Data (3 buckets)/Test/Over_Far (621).png
# ['119' '111' '71' ... '98' '63' '0']
# Layer One Data (3 buckets)/Test/Over_Far (627).png
# ['139' '130' '123' ... '132' '123' '0']
# Layer One Data (3 buckets)/Test/Over_Far (634).png
# ['133' '124' '120' ... '137' '129' '0']
# Layer One Data (3 buckets)/Test/Over_Far (641).png
# ['131' '121' '117' ... '157' '139' '0']
# Layer One Data (3 buckets)/Test/Over_Far (648).png
# ['111' '109' '73' ... '148' '98' '0']
# Layer One Data (3 buckets)/Test/Over_Far (65).png
# ['114' '97' '134' ... '79' '115' '0']
# Layer One Data (3 buckets)/Test/Over_Far (71).png
# ['118' '100' '135' ... '77' '114' '0']
# Layer One Data (3 buckets)/Test/Over_Far (72).png
# ['121' '103' '138' ... '78' '116' '0']
# Layer One Data (3 buckets)/Test/Over_Far (8).png
# ['124' '116' '173' ... '74' '128' '0']
# Layer One Data (3 buckets)/Test/Over_Far (82).png
# ['122' '105' '139' ... '86' '123' '0']
# Layer One Data (3 buckets)/Test/Over_Far (83).png
# ['116' '98' '138' ... '70' '120' '0']
# Layer One Data (3 buckets)/Test/Over_Far (84).png
# ['115' '97' '139' ... '69' '121' '0']
# Layer One Data (3 buckets)/Test/Over_Far (88).png
# ['109' '93' '128' ... '74' '114' '0']
# Layer One Data (3 buckets)/Test/Over_Far (94).png
# ['99' '82' '116' ... '77' '115' '0']
# Layer One Data (3 buckets)/Test/Over_Far (96).png
# ['87' '69' '105' ... '77' '115' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (1).png
# ['103' '99' '123' ... '53' '77' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (109).png
# ['148' '135' '173' ... '82' '122' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (118).png
# ['147' '135' '174' ... '80' '119' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (12).png
# ['120' '110' '138' ... '62' '94' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (120).png
# ['147' '134' '173' ... '82' '122' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (122).png
# ['141' '130' '168' ... '78' '118' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (124).png
# ['138' '126' '164' ... '79' '118' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (128).png
# ['134' '122' '160' ... '79' '114' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (129).png
# ['138' '126' '165' ... '78' '113' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (130).png
# ['137' '126' '163' ... '77' '114' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (132).png
# ['128' '118' '151' ... '72' '106' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (133).png
# ['130' '119' '153' ... '71' '106' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (134).png
# ['131' '120' '154' ... '71' '107' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (144).png
# ['123' '114' '148' ... '70' '104' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (150).png
# ['115' '106' '139' ... '68' '100' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (153).png
# ['117' '107' '144' ... '65' '100' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (162).png
# ['113' '103' '139' ... '61' '96' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (166).png
# ['114' '104' '142' ... '64' '99' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (167).png
# ['113' '104' '134' ... '65' '94' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (171).png
# ['107' '98' '127' ... '66' '95' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (174).png
# ['114' '105' '142' ... '66' '99' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (178).png
# ['112' '103' '132' ... '63' '92' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (18).png
# ['113' '103' '140' ... '67' '101' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (181).png
# ['112' '103' '131' ... '62' '91' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (182).png
# ['116' '106' '134' ... '62' '93' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (186).png
# ['114' '106' '135' ... '64' '96' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (198).png
# ['99' '94' '121' ... '55' '80' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (207).png
# ['96' '91' '115' ... '53' '77' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (21).png
# ['141' '128' '164' ... '76' '114' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (212).png
# ['98' '93' '119' ... '56' '78' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (221).png
# ['150' '138' '169' ... '81' '117' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (225).png
# ['159' '138' '173' ... '84' '123' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (234).png
# ['138' '127' '162' ... '76' '115' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (247).png
# ['131' '119' '153' ... '71' '106' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (248).png
# ['132' '120' '153' ... '69' '105' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (251).png
# ['132' '121' '155' ... '71' '106' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (254).png
# ['126' '117' '149' ... '69' '105' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (255).png
# ['127' '117' '153' ... '71' '104' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (258).png
# ['119' '107' '140' ... '72' '106' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (261).png
# ['128' '118' '151' ... '70' '105' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (262).png
# ['125' '115' '148' ... '68' '102' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (265).png
# ['125' '114' '148' ... '67' '101' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (267).png
# ['126' '115' '146' ... '66' '101' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (291).png
# ['117' '107' '136' ... '61' '93' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (294).png
# ['123' '111' '143' ... '64' '98' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (297).png
# ['122' '113' '145' ... '66' '99' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (298).png
# ['117' '109' '139' ... '62' '94' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (315).png
# ['113' '103' '131' ... '60' '91' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (334).png
# ['142' '130' '162' ... '74' '112' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (337).png
# ['142' '131' '167' ... '76' '115' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (338).png
# ['139' '127' '163' ... '79' '117' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (353).png
# ['130' '116' '145' ... '69' '106' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (354).png
# ['133' '119' '148' ... '69' '105' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (357).png
# ['132' '120' '152' ... '71' '106' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (363).png
# ['120' '109' '148' ... '72' '111' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (370).png
# ['122' '111' '146' ... '66' '103' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (374).png
# ['121' '110' '137' ... '65' '98' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (381).png
# ['120' '110' '147' ... '65' '101' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (387).png
# ['111' '101' '131' ... '67' '96' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (389).png
# ['118' '107' '145' ... '66' '100' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (402).png
# ['128' '112' '135' ... '66' '97' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (415).png
# ['120' '110' '141' ... '64' '98' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (416).png
# ['117' '106' '134' ... '63' '97' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (421).png
# ['118' '105' '134' ... '60' '95' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (430).png
# ['113' '103' '133' ... '64' '96' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (434).png
# ['145' '133' '169' ... '81' '118' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (442).png
# ['143' '129' '163' ... '74' '110' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (443).png
# ['137' '123' '158' ... '73' '110' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (445).png
# ['142' '131' '165' ... '73' '109' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (450).png
# ['139' '128' '163' ... '76' '111' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (454).png
# ['128' '117' '151' ... '75' '109' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (455).png
# ['128' '117' '152' ... '77' '109' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (458).png
# ['131' '121' '160' ... '71' '110' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (464).png
# ['133' '121' '152' ... '69' '102' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (466).png
# ['129' '117' '147' ... '69' '103' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (47).png
# ['133' '122' '157' ... '75' '110' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (470).png
# ['137' '127' '161' ... '73' '107' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (472).png
# ['128' '119' '157' ... '69' '105' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (475).png
# ['120' '109' '147' ... '72' '109' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (476).png
# ['122' '111' '149' ... '73' '111' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (477).png
# ['121' '112' '142' ... '70' '100' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (50).png
# ['128' '118' '152' ... '76' '110' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (501).png
# ['123' '114' '147' ... '62' '96' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (51).png
# ['126' '114' '154' ... '75' '113' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (517).png
# ['116' '106' '136' ... '68' '100' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (52).png
# ['120' '109' '150' ... '73' '112' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (521).png
# ['127' '118' '148' ... '66' '100' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (528).png
# ['119' '109' '141' ... '71' '102' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (531).png
# ['120' '111' '149' ... '65' '102' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (537).png
# ['119' '108' '134' ... '61' '92' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (55).png
# ['130' '118' '161' ... '73' '110' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (551).png
# ['104' '75' '118' ... '62' '130' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (553).png
# ['125' '99' '120' ... '76' '123' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (554).png
# ['138' '110' '124' ... '81' '124' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (555).png
# ['140' '110' '123' ... '79' '121' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (556).png
# ['141' '101' '120' ... '73' '127' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (569).png
# ['152' '140' '133' ... '111' '107' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (577).png
# ['144' '133' '127' ... '110' '106' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (585).png
# ['97' '94' '64' ... '110' '70' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (588).png
# ['113' '109' '82' ... '89' '61' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (593).png
# ['139' '124' '113' ... '103' '94' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (597).png
# ['104' '104' '75' ... '122' '83' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (599).png
# ['152' '114' '133' ... '76' '135' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (607).png
# ['133' '94' '126' ... '70' '133' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (612).png
# ['121' '92' '108' ... '72' '113' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (614).png
# ['138' '110' '119' ... '72' '117' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (615).png
# ['150' '118' '124' ... '75' '118' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (616).png
# ['153' '121' '126' ... '77' '119' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (617).png
# ['247' '204' '184' ... '86' '139' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (621).png
# ['102' '97' '69' ... '79' '51' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (625).png
# ['130' '121' '116' ... '98' '96' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (631).png
# ['120' '106' '97' ... '99' '89' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (640).png
# ['139' '123' '109' ... '92' '88' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (67).png
# ['118' '108' '147' ... '64' '102' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (74).png
# ['118' '104' '129' ... '68' '98' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (86).png
# ['127' '112' '139' ... '63' '97' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (91).png
# ['120' '104' '131' ... '70' '100' '0']
# Layer One Data (3 buckets)/Test/Over_HighPressure (98).png
# ['131' '115' '144' ... '69' '104' '0']
# Layer One Data (3 buckets)/Test/Under_Close (1).png
# ['131' '119' '155' ... '82' '116' '2']
# Layer One Data (3 buckets)/Test/Under_Close (106).png
# ['146' '136' '164' ... '79' '112' '2']
# Layer One Data (3 buckets)/Test/Under_Close (107).png
# ['141' '130' '158' ... '79' '111' '2']
# Layer One Data (3 buckets)/Test/Under_Close (110).png
# ['141' '130' '166' ... '80' '116' '2']
# Layer One Data (3 buckets)/Test/Under_Close (116).png
# ['140' '129' '158' ... '80' '111' '2']
# Layer One Data (3 buckets)/Test/Under_Close (117).png
# ['138' '129' '158' ... '78' '109' '2']
# Layer One Data (3 buckets)/Test/Under_Close (122).png
# ['140' '126' '159' ... '75' '112' '2']
# Layer One Data (3 buckets)/Test/Under_Close (130).png
# ['137' '126' '162' ... '79' '115' '2']
# Layer One Data (3 buckets)/Test/Under_Close (134).png
# ['139' '127' '163' ... '81' '118' '2']
# Layer One Data (3 buckets)/Test/Under_Close (137).png
# ['146' '135' '165' ... '82' '117' '2']
# Layer One Data (3 buckets)/Test/Under_Close (15).png
# ['80' '57' '101' ... '103' '121' '2']
# Layer One Data (3 buckets)/Test/Under_Close (153).png
# ['134' '124' '160' ... '83' '117' '2']
# Layer One Data (3 buckets)/Test/Under_Close (163).png
# ['139' '128' '162' ... '78' '114' '2']
# Layer One Data (3 buckets)/Test/Under_Close (164).png
# ['144' '134' '169' ... '79' '116' '2']
# Layer One Data (3 buckets)/Test/Under_Close (169).png
# ['131' '116' '145' ... '82' '110' '2']
# Layer One Data (3 buckets)/Test/Under_Close (181).png
# ['136' '123' '157' ... '75' '112' '2']
# Layer One Data (3 buckets)/Test/Under_Close (19).png
# ['119' '97' '142' ... '105' '129' '2']
# Layer One Data (3 buckets)/Test/Under_Close (192).png
# ['145' '126' '152' ... '76' '110' '2']
# Layer One Data (3 buckets)/Test/Under_Close (20).png
# ['103' '82' '129' ... '110' '129' '2']
# Layer One Data (3 buckets)/Test/Under_Close (201).png
# ['133' '122' '158' ... '81' '116' '2']
# Layer One Data (3 buckets)/Test/Under_Close (21).png
# ['93' '73' '119' ... '100' '123' '2']
# Layer One Data (3 buckets)/Test/Under_Close (210).png
# ['142' '126' '158' ... '77' '115' '2']
# Layer One Data (3 buckets)/Test/Under_Close (211).png
# ['152' '134' '166' ... '76' '115' '2']
# Layer One Data (3 buckets)/Test/Under_Close (214).png
# ['131' '119' '156' ... '81' '116' '2']
# Layer One Data (3 buckets)/Test/Under_Close (217).png
# ['141' '126' '156' ... '77' '111' '2']
# Layer One Data (3 buckets)/Test/Under_Close (218).png
# ['140' '125' '153' ... '77' '108' '2']
# Layer One Data (3 buckets)/Test/Under_Close (22).png
# ['84' '63' '109' ... '98' '126' '2']
# Layer One Data (3 buckets)/Test/Under_Close (225).png
# ['135' '120' '153' ... '76' '114' '2']
# Layer One Data (3 buckets)/Test/Under_Close (228).png
# ['140' '129' '165' ... '77' '114' '2']
# Layer One Data (3 buckets)/Test/Under_Close (229).png
# ['126' '114' '150' ... '80' '113' '2']
# Layer One Data (3 buckets)/Test/Under_Close (234).png
# ['135' '125' '153' ... '76' '107' '2']
# Layer One Data (3 buckets)/Test/Under_Close (235).png
# ['135' '125' '152' ... '77' '108' '2']
# Layer One Data (3 buckets)/Test/Under_Close (236).png
# ['138' '128' '154' ... '76' '106' '2']
# Layer One Data (3 buckets)/Test/Under_Close (238).png
# ['141' '128' '159' ... '75' '114' '2']
# Layer One Data (3 buckets)/Test/Under_Close (250).png
# ['137' '122' '152' ... '80' '110' '2']
# Layer One Data (3 buckets)/Test/Under_Close (260).png
# ['140' '127' '158' ... '74' '111' '2']
# Layer One Data (3 buckets)/Test/Under_Close (262).png
# ['130' '116' '139' ... '74' '105' '2']
# Layer One Data (3 buckets)/Test/Under_Close (266).png
# ['139' '128' '153' ... '77' '107' '2']
# Layer One Data (3 buckets)/Test/Under_Close (275).png
# ['152' '139' '176' ... '82' '120' '2']
# Layer One Data (3 buckets)/Test/Under_Close (276).png
# ['148' '136' '174' ... '81' '118' '2']
# Layer One Data (3 buckets)/Test/Under_Close (282).png
# ['132' '120' '149' ... '84' '112' '2']
# Layer One Data (3 buckets)/Test/Under_Close (298).png
# ['141' '129' '165' ... '81' '116' '2']
# Layer One Data (3 buckets)/Test/Under_Close (299).png
# ['143' '131' '168' ... '79' '116' '2']
# Layer One Data (3 buckets)/Test/Under_Close (31).png
# ['108' '90' '129' ... '104' '121' '2']
# Layer One Data (3 buckets)/Test/Under_Close (311).png
# ['141' '129' '165' ... '78' '114' '2']
# Layer One Data (3 buckets)/Test/Under_Close (312).png
# ['141' '130' '166' ... '78' '112' '2']
# Layer One Data (3 buckets)/Test/Under_Close (313).png
# ['138' '127' '162' ... '78' '113' '2']
# Layer One Data (3 buckets)/Test/Under_Close (322).png
# ['144' '131' '166' ... '77' '113' '2']
# Layer One Data (3 buckets)/Test/Under_Close (330).png
# ['128' '116' '143' ... '83' '110' '2']
# Layer One Data (3 buckets)/Test/Under_Close (332).png
# ['142' '126' '154' ... '76' '108' '2']
# ...
# Layer One Data (3 buckets)/Training/Under_LowPressure (513).png
# ['129' '118' '152' ... '73' '108' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (514).png
# ['128' '117' '157' ... '71' '111' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (515).png
# ['130' '119' '163' ... '71' '111' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (516).png
# ['127' '116' '158' ... '72' '111' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (518).png
# ['121' '108' '149' ... '74' '112' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (519).png
# ['118' '107' '138' ... '74' '106' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (520).png
# ['148' '134' '177' ... '81' '123' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (522).png
# ['143' '131' '170' ... '84' '121' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (523).png
# ['143' '129' '170' ... '85' '123' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (524).png
# ['145' '132' '171' ... '76' '116' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (525).png
# ['144' '132' '169' ... '78' '117' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (526).png
# ['148' '135' '173' ... '79' '119' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (527).png
# ['146' '135' '173' ... '79' '116' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (529).png
# ['144' '131' '169' ... '82' '118' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (53).png
# ['144' '131' '168' ... '76' '118' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (530).png
# ['137' '125' '163' ... '82' '118' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (532).png
# ['134' '121' '161' ... '85' '119' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (533).png
# ['133' '121' '157' ... '84' '119' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (534).png
# ['135' '122' '159' ... '82' '119' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (535).png
# ['136' '123' '161' ... '82' '116' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (536).png
# ['141' '129' '168' ... '82' '118' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (538).png
# ['142' '130' '167' ... '76' '116' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (539).png
# ['142' '131' '168' ... '77' '115' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (54).png
# ['145' '132' '171' ... '77' '117' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (540).png
# ['139' '127' '165' ... '76' '114' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (541).png
# ['139' '128' '164' ... '74' '113' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (542).png
# ['140' '127' '165' ... '73' '113' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (543).png
# ['141' '128' '164' ... '75' '112' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (544).png
# ['142' '129' '165' ... '74' '113' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (545).png
# ['140' '127' '164' ... '75' '113' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (546).png
# ['142' '128' '165' ... '75' '114' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (547).png
# ['140' '128' '163' ... '74' '112' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (548).png
# ['136' '125' '163' ... '75' '112' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (549).png
# ['140' '129' '166' ... '75' '113' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (550).png
# ['140' '131' '170' ... '75' '114' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (552).png
# ['168' '132' '136' ... '73' '129' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (557).png
# ['137' '121' '140' ... '118' '130' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (558).png
# ['132' '122' '121' ... '99' '96' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (559).png
# ['131' '116' '116' ... '120' '112' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (56).png
# ['141' '131' '167' ... '77' '119' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (560).png
# ['127' '113' '115' ... '128' '120' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (561).png
# ['115' '105' '108' ... '125' '117' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (562).png
# ['109' '99' '101' ... '120' '109' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (563).png
# ['108' '98' '96' ... '111' '103' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (564).png
# ['138' '122' '122' ... '90' '96' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (565).png
# ['130' '113' '115' ... '104' '107' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (566).png
# ['125' '109' '109' ... '113' '108' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (567).png
# ['115' '100' '99' ... '119' '106' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (568).png
# ['86' '68' '115' ... '120' '142' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (57).png
# ['143' '131' '170' ... '81' '118' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (570).png
# ['142' '124' '122' ... '92' '95' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (571).png
# ['130' '113' '112' ... '93' '97' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (572).png
# ['145' '127' '123' ... '95' '99' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (573).png
# ['143' '124' '125' ... '95' '103' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (574).png
# ['98' '82' '88' ... '87' '90' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (575).png
# ['132' '114' '113' ... '96' '98' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (576).png
# ['129' '111' '111' ... '103' '102' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (578).png
# ['125' '108' '107' ... '86' '93' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (579).png
# ['126' '108' '112' ... '87' '96' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (58).png
# ['140' '127' '166' ... '81' '118' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (580).png
# ['132' '110' '129' ... '118' '131' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (581).png
# ['115' '97' '104' ... '121' '114' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (582).png
# ['101' '90' '97' ... '115' '111' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (583).png
# ['94' '79' '126' ... '124' '148' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (584).png
# ['134' '114' '130' ... '95' '115' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (586).png
# ['136' '114' '133' ... '104' '125' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (587).png
# ['111' '94' '100' ... '119' '112' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (589).png
# ['113' '94' '130' ... '133' '150' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (59).png
# ['134' '121' '160' ... '82' '118' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (590).png
# ['121' '102' '134' ... '133' '150' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (591).png
# ['135' '119' '125' ... '88' '100' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (592).png
# ['138' '121' '124' ... '91' '101' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (594).png
# ['111' '101' '107' ... '117' '113' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (595).png
# ['89' '81' '106' ... '232' '235' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (596).png
# ['111' '106' '124' ... '201' '204' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (598).png
# ['108' '103' '71' ... '92' '53' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (6).png
# ['130' '117' '154' ... '80' '116' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (60).png
# ['135' '122' '159' ... '83' '119' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (600).png
# ['120' '109' '108' ... '116' '106' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (601).png
# ['111' '100' '98' ... '128' '108' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (602).png
# ['108' '97' '98' ... '123' '110' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (603).png
# ['138' '118' '114' ... '96' '99' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (604).png
# ['139' '118' '114' ... '97' '101' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (605).png
# ['140' '119' '117' ... '98' '102' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (606).png
# ['154' '132' '123' ... '100' '102' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (608).png
# ['150' '135' '131' ... '104' '111' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (609).png
# ['146' '131' '128' ... '105' '108' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (61).png
# ['138' '126' '164' ... '81' '117' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (610).png
# ['144' '130' '128' ... '105' '110' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (611).png
# ['125' '112' '111' ... '125' '114' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (613).png
# ['119' '106' '109' ... '126' '119' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (618).png
# ['114' '104' '107' ... '122' '113' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (619).png
# ['115' '105' '107' ... '123' '112' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (62).png
# ['141' '130' '167' ... '81' '118' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (620).png
# ['109' '99' '101' ... '121' '111' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (622).png
# ['107' '97' '99' ... '117' '104' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (623).png
# ['136' '121' '122' ... '90' '96' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (624).png
# ['136' '120' '122' ... '89' '96' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (626).png
# ['139' '122' '121' ... '90' '96' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (627).png
# ['138' '121' '120' ... '89' '94' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (628).png
# ['138' '121' '120' ... '90' '96' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (629).png
# ['138' '122' '121' ... '92' '98' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (63).png
# ['143' '131' '170' ... '79' '117' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (630).png
# ['138' '122' '121' ... '92' '95' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (632).png
# ['143' '125' '122' ... '91' '96' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (633).png
# ['146' '128' '124' ... '93' '99' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (634).png
# ['145' '128' '124' ... '93' '99' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (635).png
# ['109' '100' '103' ... '119' '111' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (636).png
# ['110' '100' '104' ... '118' '109' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (637).png
# ['110' '97' '95' ... '113' '101' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (638).png
# ['111' '97' '96' ... '113' '101' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (639).png
# ['110' '96' '94' ... '115' '103' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (64).png
# ['141' '130' '167' ... '78' '116' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (641).png
# ['111' '97' '96' ... '115' '101' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (642).png
# ['106' '97' '99' ... '116' '106' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (643).png
# ['105' '96' '99' ... '117' '108' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (644).png
# ['107' '98' '99' ... '118' '108' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (645).png
# ['104' '94' '94' ... '108' '97' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (646).png
# ['107' '98' '95' ... '108' '99' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (647).png
# ['110' '100' '97' ... '109' '101' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (648).png
# ['164' '128' '132' ... '66' '122' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (649).png
# ['166' '130' '134' ... '66' '124' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (65).png
# ['143' '131' '168' ... '76' '115' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (650).png
# ['157' '119' '139' ... '81' '139' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (66).png
# ['141' '127' '162' ... '76' '117' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (68).png
# ['138' '127' '165' ... '77' '114' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (69).png
# ['140' '129' '166' ... '78' '116' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (7).png
# ['132' '121' '158' ... '77' '114' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (70).png
# ['140' '128' '164' ... '76' '113' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (71).png
# ['140' '128' '164' ... '75' '112' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (72).png
# ['135' '123' '159' ... '73' '110' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (73).png
# ['137' '124' '161' ... '73' '113' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (75).png
# ['139' '125' '161' ... '76' '113' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (76).png
# ['139' '126' '160' ... '75' '113' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (77).png
# ['140' '127' '160' ... '75' '114' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (78).png
# ['138' '125' '162' ... '73' '110' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (79).png
# ['136' '123' '157' ... '72' '111' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (8).png
# ['135' '124' '160' ... '78' '114' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (80).png
# ['137' '126' '161' ... '74' '111' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (81).png
# ['139' '127' '163' ... '76' '112' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (82).png
# ['140' '129' '166' ... '77' '115' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (83).png
# ['135' '124' '161' ... '76' '111' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (84).png
# ['133' '122' '160' ... '78' '113' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (85).png
# ['130' '118' '155' ... '79' '116' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (87).png
# ['127' '115' '151' ... '80' '113' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (88).png
# ['129' '117' '153' ... '80' '115' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (89).png
# ['134' '123' '160' ... '77' '112' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (9).png
# ['134' '125' '161' ... '76' '112' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (90).png
# ['136' '124' '162' ... '76' '112' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (92).png
# ['136' '124' '159' ... '74' '110' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (93).png
# ['133' '121' '157' ... '72' '110' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (94).png
# ['135' '123' '158' ... '71' '110' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (95).png
# ['138' '124' '160' ... '75' '113' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (96).png
# ['134' '122' '155' ... '73' '110' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (97).png
# ['135' '122' '157' ... '74' '111' '2']
# Layer One Data (3 buckets)/Training/Under_LowPressure (99).png
# ['136' '123' '158' ... '74' '111' '2']
